# %%
import numpy as np
import pandas as pd
from pandas import DataFrame as df
import datetime as dt
from datetime import timedelta
import json
import os
import csv
import matplotlib.pyplot as plt

# %%
localdir=os.getcwd()
# localdir

# %%
folder_list=[folder for folder in os.listdir(localdir) if 'Agents_' in folder]
print(len(folder_list), os.listdir(folder_list[0]))
# Out:
# 24 ['2024-09-05-9.log', '2024-09-05-9.log.gz', 'Agents_A10.json']

# %%
ACCEPTED = 'ACCEPTED'
DECLINED = 'DECLINED'
CANCELLED = 'CANCELLED'

game_trades_df_dict = {}
game_final_df_dict = {}
game_list = []
gametype_list = []
winner_list = []
score_list = []

for folder in folder_list:
    print(folder)
    score_file=[item for item in os.listdir(folder) if '.json' in item][0]
    print(score_file)
    data=open(os.path.join(localdir,folder,score_file), encoding='utf8')
    data_load=json.load(data)
    trades_df=df.from_records(data_load["trades"])
    for ind in trades_df.index:
        trades_df.loc[ind,"beginTimestamp"]=pd.Timestamp(trades_df.loc[ind,"beginTimestamp"])
        trades_df.loc[ind,"endTimestamp"]=pd.Timestamp(trades_df.loc[ind,"endTimestamp"])
    print(trades_df.shape, folder)
    # trades_df = trades_df[(trades_df['status']==ACCEPTED)]
    game_trades_df_dict[folder] = trades_df
    # final_df=df.from_records(data_load['participants'])
    # game_final_df_dict[folder] = final_df
    # winner_list.append(data_load['winner'])
    # game_list.append(folder.split('_')[1])
    # if 'A' in folder.split('_')[1]:
        # gametype_list.append('Competitive')
    # elif 'B' in folder.split('_')[1]:
        # gametype_list.append('Baseline')
    # else:
        # gametype_list.append('Cooperative')
    # score_list.append(data_load['score'])

# winner_df = df({'game':game_list, 'gametype':gametype_list, 'winner':winner_list,'score':score_list})
# Out:
# Agents_A10
# Agents_A10.json
# (54, 14) Agents_A10
# Agents_A3
# Agents_A3.json
# (36, 14) Agents_A3
# Agents_A4
# Agents_A4.json
# (64, 14) Agents_A4
# Agents_A5
# Agents_A5.json
# (48, 14) Agents_A5
# Agents_A6
# Agents_A6.json
# (34, 14) Agents_A6
# Agents_A7
# Agents_A7.json
# (35, 14) Agents_A7
# Agents_A8
# Agents_A8.json
# (65, 14) Agents_A8
# Agents_A9
# Agents_A9.json
# (32, 14) Agents_A9
# Agents_B10
# Agents_B10.json
# (60, 14) Agents_B10
# Agents_B3
# Agents_B3.json
# (68, 14) Agents_B3
# Agents_B4
# Agents_B4.json
# (92, 14) Agents_B4
# Agents_B5
# Agents_B5.json
# (61, 14) Agents_B5
# Agents_B6
# Agent_B6.json
# (50, 14) Agents_B6
# Agents_B7
# Agents_B7.json
# (54, 14) Agents_B7
# Agents_B8
# Agents_B8.json
# (47, 14) Agents_B8
# Agents_B9
# Agents_B9.json
# (68, 14) Agents_B9
# Agents_C1
# Agents_C1.json
# (60, 14) Agents_C1
# Agents_C2
# Agents_C2.json
# (53, 14) Agents_C2
# Agents_C3
# Agents_C3.json
# (60, 14) Agents_C3
# Agents_C4
# Agents_C4.json
# (52, 14) Agents_C4
# Agents_C5
# Agents_C5.json
# (56, 14) Agents_C5
# Agents_C6
# Agents_C6.json
# (60, 14) Agents_C6
# Agents_C7
# Agents_C7.json
# (61, 14) Agents_C7
# Agents_C8
# Agents_C8.json
# (44, 14) Agents_C8

# %%
trades_result_dict = {'gametype': [], 'game': [], 'player': [],
                      'trades_requester': [], 'trades_requester_accept': [],
                      'trades_requester_cancel': [], 'trades_requester_decline': [],
                      'trades_requested': [], 'trades_requested_accept': [],
                      'trades_requested_cancel': [], 'trades_requested_decline': []}
gametype_list = []
game_list = []
player_list = []
trades_requester_list = []
trades_requester_accept_list = []
# trades_requester_accept_percent_list = []
trades_requester_cancel_list = []
trades_requester_decline_list = []

trades_requested_list = []
trades_requested_accept_list = []
# trades_requested_accept_percent_list = []
trades_requested_cancel_list = []
trades_requested_decline_list = []

for filename in game_trades_df_dict:
    print(filename)
    player_set = set(np.unique(game_trades_df_dict[filename]['requester'])) | set(np.unique(game_trades_df_dict[filename]['requested']))
    print(player_set, len(player_set))
    for player in player_set:
        player_trades_df = game_trades_df_dict[filename]
        player_trades_requester_df = player_trades_df[player_trades_df['requester']==player]
        player_trades_requested_df = player_trades_df[player_trades_df['requested']==player]
        print(player_trades_requester_df.shape, player_trades_requested_df.shape)        
        player_trades_df = player_trades_df[(player_trades_df['requester']==player) | (player_trades_df['requested']==player)]
        print(player, player_trades_df.shape)

        player_trades_requester_accept_df = player_trades_requester_df[player_trades_requester_df['status']==ACCEPTED]
        player_trades_requester_cancel_df = player_trades_requester_df[player_trades_requester_df['status']==CANCELLED]
        player_trades_requester_decline_df = player_trades_requester_df[player_trades_requester_df['status']==DECLINED]
        print(player_trades_requester_accept_df.shape, player_trades_requester_cancel_df.shape, player_trades_requester_decline_df.shape) 
        player_trades_requested_accept_df = player_trades_requested_df[player_trades_requested_df['status']==ACCEPTED]
        player_trades_requested_cancel_df = player_trades_requested_df[player_trades_requested_df['status']==CANCELLED]
        player_trades_requested_decline_df = player_trades_requested_df[player_trades_requested_df['status']==DECLINED]
        print(player_trades_requested_accept_df.shape, player_trades_requested_cancel_df.shape, player_trades_requested_decline_df.shape) 
        player_trades_accepted_df = player_trades_df[player_trades_df['status']==ACCEPTED]
        print(ACCEPTED, ' = ', player_trades_accepted_df.shape)
        player_trades_cancelled_df = player_trades_df[player_trades_df['status']==CANCELLED]
        print(CANCELLED, ' = ', player_trades_cancelled_df.shape)
        player_trades_declined_df = player_trades_df[player_trades_df['status']==DECLINED]
        print(DECLINED, ' = ', player_trades_declined_df.shape)
        print('################')
        game_list.append(filename.split('_')[1])
        if 'A' in filename.split('_')[1]:
            gametype_list.append('Competitive')
        elif 'B' in filename.split('_')[1]:
            gametype_list.append('Baseline')
        else:
            gametype_list.append('Cooperative')
        player_list.append(player)
        trades_requester_list.append(player_trades_requester_df.shape[0])
        trades_requester_accept_list.append(player_trades_requester_accept_df.shape[0])
        trades_requester_cancel_list.append(player_trades_requester_cancel_df.shape[0])
        trades_requester_decline_list.append(player_trades_requester_decline_df.shape[0])
        
        trades_requested_list.append(player_trades_requested_df.shape[0])
        trades_requested_accept_list.append(player_trades_requested_accept_df.shape[0])
        trades_requested_cancel_list.append(player_trades_requested_cancel_df.shape[0])
        trades_requested_decline_list.append(player_trades_requested_decline_df.shape[0])

trades_result_dict = {'gametype': gametype_list, 'game': game_list, 'player': player_list,
                      'trades_requester': trades_requester_list, 'trades_requester_accept': trades_requester_accept_list,
                      'trades_requester_cancel': trades_requester_cancel_list, 'trades_requester_decline': trades_requester_decline_list,
                      'trades_requested': trades_requested_list, 'trades_requested_accept': trades_requested_accept_list,
                      'trades_requested_cancel': trades_requested_cancel_list, 'trades_requested_decline': trades_requested_decline_list}
trades_result_df = df.from_dict(trades_result_dict)
# Out:
# Agents_A10
# {'Lamar', 'Sokka', 'Sarah', 'Alan', 'Kalyani'} 5
# (4, 14) (17, 14)
# Lamar (21, 14)
# (2, 14) (0, 14) (0, 14)
# (8, 14) (2, 14) (4, 14)
# ACCEPTED  =  (10, 14)
# CANCELLED  =  (2, 14)
# DECLINED  =  (4, 14)
# ################
# (12, 14) (13, 14)
# Sokka (25, 14)
# (5, 14) (2, 14) (2, 14)
# (2, 14) (3, 14) (5, 14)
# ACCEPTED  =  (7, 14)
# CANCELLED  =  (5, 14)
# DECLINED  =  (7, 14)
# ################
# (14, 14) (3, 14)
# Sarah (17, 14)
# (10, 14) (2, 14) (1, 14)
# (1, 14) (0, 14) (1, 14)
# ACCEPTED  =  (11, 14)
# CANCELLED  =  (2, 14)
# DECLINED  =  (2, 14)
# ################
# (18, 14) (3, 14)
# Alan (21, 14)
# (4, 14) (1, 14) (11, 14)
# (3, 14) (0, 14) (0, 14)
# ACCEPTED  =  (7, 14)
# CANCELLED  =  (1, 14)
# DECLINED  =  (11, 14)
# ################
# (6, 14) (18, 14)
# Kalyani (24, 14)
# (5, 14) (0, 14) (0, 14)
# (12, 14) (0, 14) (4, 14)
# ACCEPTED  =  (17, 14)
# CANCELLED  =  (0, 14)
# DECLINED  =  (4, 14)
# ################
# Agents_A3
# {'Lamar', 'Sokka', 'Sarah', 'Alan', 'Kalyani'} 5
# (3, 14) (9, 14)
# Lamar (12, 14)
# (3, 14) (0, 14) (0, 14)
# (4, 14) (1, 14) (3, 14)
# ACCEPTED  =  (7, 14)
# CANCELLED  =  (1, 14)
# DECLINED  =  (3, 14)
# ################
# (4, 14) (8, 14)
# Sokka (12, 14)
# (3, 14) (0, 14) (0, 14)
# (3, 14) (0, 14) (4, 14)
# ACCEPTED  =  (6, 14)
# CANCELLED  =  (0, 14)
# DECLINED  =  (4, 14)
# ################
# (6, 14) (13, 14)
# Sarah (19, 14)
# (3, 14) (0, 14) (2, 14)
# (7, 14) (0, 14) (5, 14)
# ACCEPTED  =  (10, 14)
# CANCELLED  =  (0, 14)
# DECLINED  =  (7, 14)
# ################
# (15, 14) (4, 14)
# Alan (19, 14)
# (7, 14) (1, 14) (5, 14)
# (3, 14) (0, 14) (0, 14)
# ACCEPTED  =  (10, 14)
# CANCELLED  =  (1, 14)
# DECLINED  =  (5, 14)
# ################
# (8, 14) (2, 14)
# Kalyani (10, 14)
# (3, 14) (0, 14) (5, 14)
# (2, 14) (0, 14) (0, 14)
# ACCEPTED  =  (5, 14)
# CANCELLED  =  (0, 14)
# DECLINED  =  (5, 14)
# ################
# Agents_A4
# {'Lamar', 'Sokka', 'Sarah', 'Alan', 'Kalyani'} 5
# (17, 14) (8, 14)
# Lamar (25, 14)
# (14, 14) (0, 14) (1, 14)
# (3, 14) (0, 14) (5, 14)
# ACCEPTED  =  (17, 14)
# CANCELLED  =  (0, 14)
# DECLINED  =  (6, 14)
# ################
# (7, 14) (18, 14)
# Sokka (25, 14)
# (6, 14) (0, 14) (1, 14)
# (11, 14) (0, 14) (6, 14)
# ACCEPTED  =  (17, 14)
# CANCELLED  =  (0, 14)
# DECLINED  =  
 14)
# CANCELLED  =  (1, 14)
# DECLINED  =  (5, 14)
# ################
# (8, 14) (18, 14)
# Alan (26, 14)
# (6, 14) (0, 14) (2, 14)
# (7, 14) (2, 14) (8, 14)
# ACCEPTED  =  (13, 14)
# CANCELLED  =  (2, 14)
# DECLINED  =  (10, 14)
# ################
# (12, 14) (9, 14)
# Kalyani (21, 14)
# (2, 14) (1, 14) (4, 14)
# (5, 14) (0, 14) (1, 14)
# ACCEPTED  =  (7, 14)
# CANCELLED  =  (1, 14)
# DECLINED  =  (5, 14)
# ################
# Agents_C8
# {'Lamar', 'Sokka', 'Sarah', 'Alan', 'Kalyani'} 5
# (25, 14) (1, 14)
# Lamar (26, 14)
# (8, 14) (0, 14) (13, 14)
# (1, 14) (0, 14) (0, 14)
# ACCEPTED  =  (9, 14)
# CANCELLED  =  (0, 14)
# DECLINED  =  (13, 14)
# ################
# (1, 14) (15, 14)
# Sokka (16, 14)
# (1, 14) (0, 14) (0, 14)
# (8, 14) (1, 14) (5, 14)
# ACCEPTED  =  (9, 14)
# CANCELLED  =  (1, 14)
# DECLINED  =  (5, 14)
# ################
# (9, 14) (10, 14)
# Sarah (19, 14)
# (5, 14) (0, 14) (3, 14)
# (2, 14) (0, 14) (8, 14)
# ACCEPTED  =  (7, 14)
# CANCELLED  =  (0, 14)
# DECLINED  =  (11, 14)
# ################
# (7, 14) (6, 14)
# Alan (13, 14)
# (5, 14) (0, 14) (2, 14)
# (3, 14) (0, 14) (3, 14)
# ACCEPTED  =  (8, 14)
# CANCELLED  =  (0, 14)
# DECLINED  =  (5, 14)
# ################
# (2, 14) (12, 14)
# Kalyani (14, 14)
# (1, 14) (1, 14) (0, 14)
# (6, 14) (0, 14) (2, 14)
# ACCEPTED  =  (7, 14)
# CANCELLED  =  (1, 14)
# DECLINED  =  (2, 14)
# ################

# %%
trades_result_df
# Out:
#         gametype game   player  trades_requester  trades_requester_accept  \
# 0    Competitive  A10    Lamar                 4                        2
# 1    Competitive  A10    Sokka                12                        5
# 2    Competitive  A10    Sarah                14                       10
# 3    Competitive  A10     Alan                18                        4
# 4    Competitive  A10  Kalyani                 6                        5
# ..           ...  ...      ...               ...                      ...
# 115  Cooperative   C8    Lamar                25                        8
# 116  Cooperative   C8    Sokka                 1                        1
# 117  Cooperative   C8    Sarah                 9                        5
# 118  Cooperative   C8     Alan                 7                        5
# 119  Cooperative   C8  Kalyani                 2                        1
#
#      trades_requester_cancel  trades_requester_decline  trades_requested  \
# 0                          0                         0                17
# 1                          2                         2                13
# 2                          2                         1                 3
# 3                          1                        11                 3
# 4                          0                         0                18
# ..                       ...                       ...               ...
# 115                        0                        13                 1
# 116                        0                         0                15
# 117                        0                         3                10
# 118                        0                         2                 6
# 119                        1                         0                12
#
#      trades_requested_accept  trades_requested_cancel  \
# 0                          8                        2
# 1                          2                        3
# 2                          1                        0
# 3                          3                        0
# 4                         12                        0
# ..                       ...                      ...
# 115                        1                        0
# 116                        8                        1
# 117                        2                        0
# 118                        3                        0
# 119                        6                        0
#
#      trades_requested_decline
# 0                           4
# 1                           5
# 2                           1
# 3                           0
# 4                           4
# ..                        ...
# 115                         0
# 116                         5
# 117                         8
# 118                         3
# 119                         2
#
# [120 rows x 11 columns]

# %%
trades_result_df.to_excel('AAMAS-Trades-Efficiency-Agents-df.xlsx')
