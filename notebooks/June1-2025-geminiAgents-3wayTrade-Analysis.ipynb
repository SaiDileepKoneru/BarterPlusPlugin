# %%
import numpy as np
import pandas as pd
from pandas import DataFrame as df
import datetime as dt
from datetime import timedelta
import json
import os
import csv
import matplotlib.pyplot as plt

# %%
localdir=os.getcwd()
# localdir

# %%
localdir
# Out:
# 'C:\\Users\\vchiluveru\\Downloads\\VB\\KL\\GRA\\Gemini'

# %%
folder_list=[folder for folder in os.listdir(localdir) if 'Gemini' in folder]
print(len(folder_list), os.listdir(folder_list[0]))
# Out:
# 24 ['Gemini_Base_1.docx', 'Gemini_Base_1.json']

# %%
# for foldername in folder_list:
#     print(os.listdir(foldername))

# %%
player_names_list = ['Alex', 'Cosmo', 'Negan', 'Sokka', 'Steve']

# %%
player_profession_dict = {}

for ent in data_load['participants']:
    player_profession_dict[ent['name']] = ent['profession'] 
player_profession_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_22476\3399294878.py in <module>
#       1 player_profession_dict = {}
#       2
# ----> 3 for ent in data_load['participants']:
#       4     player_profession_dict[ent['name']] = ent['profession']
#       5 player_profession_dict
#
# NameError: name 'data_load' is not defined

# %%
ACCEPTED = 'ACCEPTED'
DECLINED = 'DECLINED'
CANCELLED = 'CANCELLED'

game_trades_df_dict = {}
game_final_df_dict = {}
game_list = []
gametype_list = []
winner_list = []
score_list = []

player_profession_dict = {}

for folder in folder_list:
    print(folder)
    score_file=[item for item in os.listdir(folder) if '.json' in item][0]
    print(score_file)
    data=open(os.path.join(localdir,folder,score_file), encoding='utf8')
    data_load=json.load(data)
    player_profession_dict[folder] = {}
    for ent in data_load['participants']:
        player_profession_dict[folder][ent['name']] = ent['profession'] 
    trades_df=df.from_records(data_load["trades"])
    for ind in trades_df.index:
        trades_df.loc[ind,"beginTimestamp"]=pd.Timestamp(trades_df.loc[ind,"beginTimestamp"])
        trades_df.loc[ind,"endTimestamp"]=pd.Timestamp(trades_df.loc[ind,"endTimestamp"])
    print(trades_df.shape, folder)
    trades_df = trades_df[(trades_df['status']==ACCEPTED)]
    print(trades_df.shape, folder)
    game_trades_df_dict[folder] = trades_df
    # final_df=df.from_records(data_load['participants'])
    # game_final_df_dict[folder] = final_df
    # winner_list.append(data_load['winner'])
    # game_list.append(folder.split('_')[1])
    # if 'A' in folder.split('_')[1]:
        # gametype_list.append('Competitive')
    # elif 'B' in folder.split('_')[1]:
        # gametype_list.append('Baseline')
    # else:
        # gametype_list.append('Cooperative')
    # score_list.append(data_load['score'])

# winner_df = df({'game':game_list, 'gametype':gametype_list, 'winner':winner_list,'score':score_list})
professions_set = set([player_profession_dict[folder][player] for folder in player_profession_dict for player in player_profession_dict[folder]])
# Out:
# GeminiBase1
# Gemini_Base_1.json
# (26, 14) GeminiBase1
# (13, 14) GeminiBase1
# GeminiBase16
# Gemini_Base_16.json
# (39, 14) GeminiBase16
# (10, 14) GeminiBase16
# GeminiBase18
# Gemini_Base_18.json
# (28, 14) GeminiBase18
# (10, 14) GeminiBase18
# GeminiBase2
# Gemini_Base_2.json
# (22, 14) GeminiBase2
# (11, 14) GeminiBase2
# GeminiBase3
# Gemini_Base_3.json
# (22, 14) GeminiBase3
# (9, 14) GeminiBase3
# GeminiBase4
# Gemini_Base_4.json
# (15, 14) GeminiBase4
# (8, 14) GeminiBase4
# GeminiBase5
# Gemini_Base_5.json
# (26, 14) GeminiBase5
# (18, 14) GeminiBase5
# GeminiBase8
# Gemini_Base_8.json
# (27, 14) GeminiBase8
# (10, 14) GeminiBase8
# GeminiComp1
# Gemini_Comp_1.json
# (18, 14) GeminiComp1
# (12, 14) GeminiComp1
# GeminiComp2
# Gemini_Comp_2.json
# (20, 14) GeminiComp2
# (3, 14) GeminiComp2
# GeminiComp3
# Gemini_Comp_3.json
# (17, 14) GeminiComp3
# (12, 14) GeminiComp3
# GeminiComp4
# Gemini_Comp_4.json
# (14, 14) GeminiComp4
# (9, 14) GeminiComp4
# GeminiComp6
# Gemini_Comp_6.json
# (22, 14) GeminiComp6
# (12, 14) GeminiComp6
# GeminiComp7
# Gemini_Comp_7.json
# (13, 14) GeminiComp7
# (6, 14) GeminiComp7
# GeminiComp8
# Gemini_Comp_8.json
# (17, 14) GeminiComp8
# (12, 14) GeminiComp8
# GeminiComp9
# Gemini_Comp_9.json
# (30, 14) GeminiComp9
# (12, 14) GeminiComp9
# GeminiCoop1
# Gemini_Coop_1.json
# (23, 14) GeminiCoop1
# (13, 14) GeminiCoop1
# GeminiCoop3
# Gemini_Coop_3.json
# (19, 14) GeminiCoop3
# (6, 14) GeminiCoop3
# GeminiCoop4
# Gemini_Coop_4.json
# (24, 14) GeminiCoop4
# (13, 14) GeminiCoop4
# GeminiCoop5
# Gemini_Coop_5.json
# (20, 14) GeminiCoop5
# (15, 14) GeminiCoop5
# GeminiCoop6
# Gemini_Coop_6.json
# (36, 14) GeminiCoop6
# (11, 14) GeminiCoop6
# GeminiCoop7
# Gemini_Coop_7.json
# (16, 14) GeminiCoop7
# (8, 14) GeminiCoop7
# GeminiCoop8
# Gemini_Coop_8.json
# (21, 14) GeminiCoop8
# (8, 14) GeminiCoop8
# GeminiCoop9
# Gemini_Coop_9.json
# (42, 14) GeminiCoop9
# (10, 14) GeminiCoop9

# %%
# def get_begin_end_scores(r):
#     endscore_dict = r['endScores']
#     beginscore_dict = r['beginScores']
#     requester_beginscore = beginscore_dict['requester']
#     requester_endscore = endscore_dict['requester']
#     requested_beginscore = beginscore_dict['requested']
#     requested_endscore = endscore_dict['requested']
#     requester_scoregain = requester_endscore - requester_beginscore
#     requested_scoregain = requested_endscore - requested_beginscore
#     total_scoregain = requester_scoregain + requested_scoregain
#     print(requester_scoregain, requested_scoregain, total_scoregain)
#     r['scoregain'] = total_scoregain
#     return r

# player_trades_df = game_trades_df_dict[filename]
# player_trades_df = player_trades_df[player_trades_df['status']==ACCEPTED]
# player_trades_df = player_trades_df.apply(get_begin_end_scores, axis=1)
# player_trades_df

# %%
'RED_GLAZED_TERRACOTTA'.lower().replace('_',' ')
# Out:
# 'red glazed terracotta'

# %%
tierItemsValueFile=open('TierITemValues.txt', encoding='utf8')
tierItemsValuelines = tierItemsValueFile.readlines()
tierItemsValueFile.close()

item_names_list = []
item_tier_list = []
item_value_list = []
itemTierValue_dict = {}
profession_items_dict = {profession: [] for profession in professions_set}

for line in tierItemsValuelines:
    # print(line)
    if 'tier1' in line:
        item_name = line.split('ItemStack(Material.')[1].split('));')[0]
        item_name = item_name.lower()
        # item_names_list.append(item_name)
        # item_tier_list.append(1)
        # item_value_list.append(1)
        # print(line)
        profession_name = line.split('tier1')[1].split('.add(')[0]
        profession_items_dict[profession_name].append(item_name)
        if item_name not in itemTierValue_dict:
            itemTierValue_dict[item_name] = {'tier': 1, 'value':1}
    elif 'tier2' in line:
        item_name = line.split('ItemStack(Material.')[1].split('));')[0]
        item_name = item_name.lower()
        # item_names_list.append(item_name)
        # item_tier_list.append(2)
        # item_value_list.append(3)
        # print(line)
        profession_name = line.split('tier2')[1].split('.add(')[0]
        profession_items_dict[profession_name].append(item_name)
        if item_name not in itemTierValue_dict:
            itemTierValue_dict[item_name] = {'tier': 2, 'value':3}
    elif 'tier3' in line:
        item_name = line.split('ItemStack(Material.')[1].split('));')[0]
        item_name = item_name.lower()
        # item_names_list.append(item_name)
        # item_tier_list.append(3)
        # item_value_list.append(10)
        # print(line)
        profession_name = line.split('tier3')[1].split('.add(')[0]
        profession_items_dict[profession_name].append(item_name)
        if item_name not in itemTierValue_dict:
            itemTierValue_dict[item_name] = {'tier': 3, 'value':10}

# itemTierValue_df = df({'item_name':item_names_list, 'tier':item_tier_list, 'value':item_value_list})
print(itemTierValue_dict)
print(profession_items_dict)
# Out:
# {'potato': {'tier': 1, 'value': 1}, 'carrot': {'tier': 1, 'value': 1}, 'wheat': {'tier': 1, 'value': 1}, 'bread': {'tier': 2, 'value': 3}, 'pumpkin': {'tier': 2, 'value': 3}, 'mushroom_stew': {'tier': 3, 'value': 10}, 'cod': {'tier': 1, 'value': 1}, 'salmon': {'tier': 1, 'value': 1}, 'tropical_fish': {'tier': 1, 'value': 1}, 'pufferfish': {'tier': 2, 'value': 3}, 'turtle_egg': {'tier': 2, 'value': 3}, 'oak_boat': {'tier': 3, 'value': 10}, 'beef': {'tier': 1, 'value': 1}, 'chicken': {'tier': 1, 'value': 1}, 'porkchop': {'tier': 1, 'value': 1}, 'cooked_beef': {'tier': 2, 'value': 3}, 'cooked_porkchop': {'tier': 2, 'value': 3}, 'rabbit_stew': {'tier': 3, 'value': 10}, 'iron_ingot': {'tier': 1, 'value': 1}, 'gold_ingot': {'tier': 1, 'value': 1}, 'coal': {'tier': 1, 'value': 1}, 'fletching_table': {'tier': 2, 'value': 3}, 'smithing_table': {'tier': 2, 'value': 3}, 'diamond_sword': {'tier': 3, 'value': 10}, 'leather': {'tier': 1, 'value': 1}, 'stick': {'tier': 1, 'value': 1}, 'lead': {'tier': 1, 'value': 1}, 'cow_spawn_egg': {'tier': 2, 'value': 3}, 'rabbit_hide': {'tier': 2, 'value': 3}, 'saddle': {'tier': 3, 'value': 10}, 'stone': {'tier': 1, 'value': 1}, 'quartz_block': {'tier': 1, 'value': 1}, 'glass': {'tier': 1, 'value': 1}, 'red_glazed_terracotta': {'tier': 2, 'value': 3}, 'blue_glazed_terracotta': {'tier': 2, 'value': 3}, 'stone_pickaxe': {'tier': 3, 'value': 10}, 'string': {'tier': 1, 'value': 1}, 'white_wool': {'tier': 1, 'value': 1}, 'blue_dye': {'tier': 1, 'value': 1}, 'sheep_spawn_egg': {'tier': 2, 'value': 3}, 'loom': {'tier': 2, 'value': 3}, 'shears': {'tier': 3, 'value': 10}, 'oak_log': {'tier': 1, 'value': 1}, 'spruce_log': {'tier': 1, 'value': 1}, 'birch_log': {'tier': 1, 'value': 1}, 'spruce_planks': {'tier': 2, 'value': 3}, 'oak_planks': {'tier': 2, 'value': 3}, 'diamond_axe': {'tier': 3, 'value': 10}}
# {'Mason': ['stone', 'quartz_block', 'glass', 'red_glazed_terracotta', 'blue_glazed_terracotta', 'stone_pickaxe'], 'Shepherd': ['string', 'white_wool', 'blue_dye', 'sheep_spawn_egg', 'loom', 'shears'], 'Leatherworker': ['leather', 'stick', 'lead', 'cow_spawn_egg', 'rabbit_hide', 'saddle'], 'Lumberjack': ['oak_log', 'spruce_log', 'birch_log', 'spruce_planks', 'oak_planks', 'diamond_axe'], 'Farmer': ['potato', 'carrot', 'wheat', 'bread', 'pumpkin', 'mushroom_stew'], 'Fisher': ['cod', 'salmon', 'tropical_fish', 'pufferfish', 'turtle_egg', 'oak_boat'], 'Butcher': ['beef', 'chicken', 'porkchop', 'cooked_beef', 'cooked_porkchop', 'rabbit_stew'], 'Blacksmith': ['iron_ingot', 'gold_ingot', 'coal', 'fletching_table', 'smithing_table', 'diamond_sword']}

# %%
def get_trade_value(r):
    request_list = r['request']
    offer_list = r['offer']
    total_trade_value = 0
    for req in request_list:
        item_name = req['resource']
        item_num = req['amount']
        item_name = item_name.lower().replace(' ', '_')
        total_value = itemTierValue_dict[item_name]['value'] * item_num
        total_trade_value += total_value
    for req in offer_list:
        item_name = req['resource']
        item_num = req['amount']
        item_name = item_name.lower().replace(' ', '_')
        total_value = itemTierValue_dict[item_name]['value'] * item_num
        total_trade_value += total_value
    r['trade_value'] = total_trade_value
    if 'Comp' in filename.split('Gemini')[-1]:
        r['game_type'] = 'Competitive'
        r['game_name'] = filename.split('GeminiComp')[-1]
    elif 'Base' in filename.split('Gemini')[-1]:
        r['game_type'] = 'Baseline'
        r['game_name'] = filename.split('GeminiBase')[-1]
    else:
        r['game_type'] = 'Cooperative'
        r['game_name'] = filename.split('GeminiCoop')[-1]
    return r

# %%
for filename in game_trades_df_dict:
    print(filename)
    trades_df = game_trades_df_dict[filename]
    trades_df = trades_df.apply(get_trade_value, axis=1)
    game_trades_df_dict[filename] = trades_df
# Out:
# GeminiBase1
# GeminiBase16
# GeminiBase18
# GeminiBase2
# GeminiBase3
# GeminiBase4
# GeminiBase5
# GeminiBase8
# GeminiComp1
# GeminiComp2
# GeminiComp3
# GeminiComp4
# GeminiComp6
# GeminiComp7
# GeminiComp8
# GeminiComp9
# GeminiCoop1
# GeminiCoop3
# GeminiCoop4
# GeminiCoop5
# GeminiCoop6
# GeminiCoop7
# GeminiCoop8
# GeminiCoop9

# %%
def get_request_non_useful_items(trades_df, player_names_list, player_profession_dict, profession_items_dict, filename):
    player_profession = {}
    player_useful_items = {}
    for player in player_names_list:
        player_profession[player] = player_profession_dict[filename][player]
        player_useful_items[player] = profession_items_dict[player_profession[player]]
    def row_wise_non_useful(row):
        p1 = row['requester']
        p2 = row['requested']

        request_list = row['request']
        request_items_list = [ent['resource'].lower().replace(' ', '_') for ent in request_list]
        request_non_useful_items_list = [item for item in request_items_list if item not in player_useful_items[p1]]
        offer_list = row['offer']
        offer_items_list = [ent['resource'].lower().replace(' ', '_') for ent in offer_list]
        offer_non_useful_items_list = [item for item in offer_items_list if item not in player_useful_items[p2]]
        row['requester_nonuseful'] = request_non_useful_items_list
        row['requested_nonuseful'] = offer_non_useful_items_list
        return row

    trades_df = trades_df.apply(row_wise_non_useful, axis=1)
    return trades_df

# %%
# three_way_trades_dict = {}

# for filename in game_trades_df_dict:
#     print(filename)
#     three_way_trades_dict[filename] = []
#     # three_way_trades_dict[filename] = {}
#     trades_df = game_trades_df_dict[filename]
#     trades_df = get_request_non_useful_items(trades_df, player_names_list, player_profession_dict, profession_items_dict, filename)
    
#     for player in player_names_list:
#         x_df = trades_df[(trades_df['requester']==player) | (trades_df['requested']==player)]

#         for i in range(len(x_df.index)-1):
#             N = len(x_df.index)
#             row = x_df.loc[x_df.index[i], :]
#             p1 = row['requester']
#             p2 = row['requested']
#             if p1 == player:
#                 # check requester_nonuseful
#                 p1_non_useful = row['requester_nonuseful']
#                 # p2_non_useful = row['requested_nonuseful']
#                 if len(p1_non_useful):
#                     # p1 got non-useful items
#                     # when does he trade these items, if at all, after how many trades
#                     for j in np.arange(1, N-i):
#                         row_n1 = x_df.loc[x_df.index[i+j], :]
#                         if row_n1['requester'] == player:
#                             # check offer items
#                             items_n1 = [ent['resource'] for ent in row_n1['offer']]
#                             items_n1 = [ent.lower().replace(' ', '_') for ent in items_n1]
#                             # within items in offer, check if at least 1 item is from previous non_useful
#                             traded_nonuseful_items_list = [item for item in items_n1 if item in p1_non_useful]
#                             if len(traded_nonuseful_items_list):
#                                 # 3-way trade occured
#                                 three_way_trades_dict[filename].append(
#                                     {'player': player, 'trade1': i+1, 'trade2': i+j+1, 'count': j,
#                                      'non_useful_items1': p1_non_useful, 'non_useful_items2': traded_nonuseful_items_list,
#                                      'game_type': row_n1['game_type'],  'game_name': row_n1['game_name'],
#                                      'trade1_ind': x_df.index[i], 'trade2_ind': x_df.index[i+j]})
#                         elif row_n1['requested'] == player:
#                             # check request items
#                             items_n1 = [ent['resource'] for ent in row_n1['request']]
#                             items_n1 = [ent.lower().replace(' ', '_') for ent in items_n1]
#                             # within items in request, check if at least 1 item is from previous non_useful
#                             traded_nonuseful_items_list = [item for item in items_n1 if item in p1_non_useful]
#                             if len(traded_nonuseful_items_list):
#                                 # 3-way trade occured
#                                 three_way_trades_dict[filename].append(
#                                     {'player': player, 'trade1': i+1, 'trade2': i+j+1, 'count': j,
#                                      'non_useful_items1': p1_non_useful, 'non_useful_items2': traded_nonuseful_items_list,
#                                      'game_type': row_n1['game_type'],  'game_name': row_n1['game_name'],
#                                      'trade1_ind': x_df.index[i], 'trade2_ind': x_df.index[i+j]})
                    
#             if p2 == player:
#                 # check requested_nonuseful
#                 # p1_non_useful = row['requester_nonuseful']
#                 p2_non_useful = row['requested_nonuseful']
#                 if len(p2_non_useful):
#                     # p2 got non-useful items
#                     # when does he trade these items, if at all, after how many trades
#                     for j in np.arange(1, N-i):
#                         row_n1 = x_df.loc[x_df.index[i+j], :]
#                         if row_n1['requester'] == player:
#                             # check offer items
#                             items_n1 = [ent['resource'] for ent in row_n1['offer']]
#                             items_n1 = [ent.lower().replace(' ', '_') for ent in items_n1]
#                             # within items in offer, check if at least 1 item is from previous non_useful
#                             traded_nonuseful_items_list = [item for item in items_n1 if item in p2_non_useful]
#                             if len(traded_nonuseful_items_list):
#                                 # 3-way trade occured
#                                 three_way_trades_dict[filename].append(
#                                     {'player': player, 'trade1': i+1, 'trade2': i+j+1, 'count': j,
#                                      'non_useful_items1': p2_non_useful, 'non_useful_items2': traded_nonuseful_items_list,
#                                      'game_type': row_n1['game_type'],  'game_name': row_n1['game_name'],
#                                      'trade1_ind': x_df.index[i], 'trade2_ind': x_df.index[i+j]})
#                         elif row_n1['requested'] == player:
#                             # check request items
#                             items_n1 = [ent['resource'] for ent in row_n1['request']]
#                             items_n1 = [ent.lower().replace(' ', '_') for ent in items_n1]
#                             # within items in request, check if at least 1 item is from previous non_useful
#                             traded_nonuseful_items_list = [item for item in items_n1 if item in p2_non_useful]
#                             if len(traded_nonuseful_items_list):
#                                 # 3-way trade occured
#                                 three_way_trades_dict[filename].append(
#                                     {'player': player, 'trade1': i+1, 'trade2': i+j+1, 'count': j,
#                                      'non_useful_items1': p2_non_useful, 'non_useful_items2': traded_nonuseful_items_list,
#                                      'game_type': row_n1['game_type'],  'game_name': row_n1['game_name'],
#                                      'trade1_ind': x_df.index[i], 'trade2_ind': x_df.index[i+j]})

# %%
three_way_trades_dict = {}

for filename in game_trades_df_dict:
    print(filename)
    three_way_trades_dict[filename] = []
    # three_way_trades_dict[filename] = {}
    trades_df = game_trades_df_dict[filename]
    trades_df = get_request_non_useful_items(trades_df, player_names_list, player_profession_dict, profession_items_dict, filename)
    
    for player in player_names_list:
        x_df = trades_df[(trades_df['requester']==player) | (trades_df['requested']==player)]
        print(player)

        for i in range(len(x_df.index)-1):
            N = len(x_df.index)
            row = x_df.loc[x_df.index[i], :]
            p1 = row['requester']
            p2 = row['requested']
            if p1 == player:
                # check requester_nonuseful
                p1_non_useful = row['requester_nonuseful']
                # p2_non_useful = row['requested_nonuseful']
                if len(p1_non_useful):
                    # p1 got non-useful items
                    # when does he trade these items, if at all, after how many trades
                    for j in np.arange(1, N-i):
                        row_n1 = x_df.loc[x_df.index[i+j], :]
                        items_n1_request = []
                        items_n1_request_amt = []
                        items_n1_request_dict = {}
                        received_useful_items_list = []
                        if row_n1['requester'] == player:
                            # check offer items
                            items_n1 = [ent['resource'] for ent in row_n1['offer']]
                            items_n1 = [ent.lower().replace(' ', '_') for ent in items_n1]
                            # within items in offer, check if at least 1 item is from previous non_useful
                            traded_nonuseful_items_list = [item for item in items_n1 if item in p1_non_useful]
                            if len(traded_nonuseful_items_list):
                                # 3-way trade occured
                                # check if the item received is useful for player too
                                # check request items
                                items_n1_request = [ent['resource'] for ent in row_n1['request']]
                                items_n1_request = [ent.lower().replace(' ', '_') for ent in items_n1_request]
                                items_n1_request_amt = [ent['amount'] for ent in row_n1['request']]
                                items_n1_request_dict = {item: amt for item, amt in zip(
                                    items_n1_request, items_n1_request_amt)}
                                player_profession = player_profession_dict[filename][player]
                                player_useful_items = profession_items_dict[player_profession]
                                received_useful_items_list = [item for item in items_n1_request if item in player_useful_items]
                                print(items_n1_request_dict)
                                print(player_useful_items)
                                print('j = ', j, 'received_useful_items: ', received_useful_items_list)
                                if len(received_useful_items_list):
                                    score_gain = 0
                                    for item in received_useful_items_list:
                                        if item in itemTierValue_dict:
                                            score_gain += (items_n1_request_dict[item]*itemTierValue_dict[item]['value'])
                                        else:
                                            # unable to find this item in the tier value directory
                                            print('unable to find tier value for item: ', item)
                                    print('3-WAY TRADE! ', i, j)
                                    three_way_trades_dict[filename].append(
                                        {'player': player, 'trade1': i+1, 'trade2': i+j+1, 'count': j,
                                         'non_useful_items1': p1_non_useful, 'non_useful_items2': traded_nonuseful_items_list,
                                         'received_useful_items': items_n1_request_dict, 'score_gain': score_gain,
                                         'game_type': row_n1['game_type'],  'game_name': row_n1['game_name'],
                                         'trade1_ind': x_df.index[i], 'trade2_ind': x_df.index[i+j]})
                        elif row_n1['requested'] == player:
                            # check request items
                            items_n1 = [ent['resource'] for ent in row_n1['request']]
                            items_n1 = [ent.lower().replace(' ', '_') for ent in items_n1]
                            # within items in request, check if at least 1 item is from previous non_useful
                            traded_nonuseful_items_list = [item for item in items_n1 if item in p1_non_useful]
                            if len(traded_nonuseful_items_list):
                                # 3-way trade occured
                                # check if the item received is useful for player too
                                # check request items
                                items_n1_request = [ent['resource'] for ent in row_n1['offer']]
                                items_n1_request = [ent.lower().replace(' ', '_') for ent in items_n1_request]
                                items_n1_request_amt = [ent['amount'] for ent in row_n1['offer']]
                                items_n1_request_dict = {item: amt for item, amt in zip(
                                    items_n1_request, items_n1_request_amt)}
                                player_profession = player_profession_dict[filename][player]
                                player_useful_items = profession_items_dict[player_profession]
                                received_useful_items_list = [item for item in items_n1_request if item in player_useful_items]
                                print(items_n1_request_dict)
                                print(player_useful_items)
                                print('j = ', j, 'received_useful_items: ', received_useful_items_list)
                                if len(received_useful_items_list):
                                    score_gain = 0
                                    for item in received_useful_items_list:
                                        if item in itemTierValue_dict:
                                            score_gain += (items_n1_request_dict[item]*itemTierValue_dict[item]['value'])
                                        else:
                                            # unable to find this item in the tier value directory
                                            print('unable to find tier value for item: ', item)
                                    print('3-WAY TRADE! ', i, j)
                                three_way_trades_dict[filename].append(
                                    {'player': player, 'trade1': i+1, 'trade2': i+j+1, 'count': j,
                                     'non_useful_items1': p1_non_useful, 'non_useful_items2': traded_nonuseful_items_list,
                                     'received_useful_items': items_n1_request_dict, 'score_gain': score_gain,
                                     'game_type': row_n1['game_type'],  'game_name': row_n1['game_name'],
                                     'trade1_ind': x_df.index[i], 'trade2_ind': x_df.index[i+j]})
                    
            if p2 == player:
                # check requested_nonuseful
                # p1_non_useful = row['requester_nonuseful']
                p2_non_useful = row['requested_nonuseful']
                if len(p2_non_useful):
                    # p2 got non-useful items
                    # when does he trade these items, if at all, after how many trades
                    for j in np.arange(1, N-i):
                        row_n1 = x_df.loc[x_df.index[i+j], :]
                        items_n1_request = []
                        items_n1_request_amt = []
                        items_n1_request_dict = {}
                        received_useful_items_list = []
                        if row_n1['requester'] == player:
                            # check offer items
                            items_n1 = [ent['resource'] for ent in row_n1['offer']]
                            items_n1 = [ent.lower().replace(' ', '_') for ent in items_n1]
                            # within items in offer, check if at least 1 item is from previous non_useful
                            traded_nonuseful_items_list = [item for item in items_n1 if item in p2_non_useful]
                            if len(traded_nonuseful_items_list):
                                # 3-way trade occured
                                # check if the item received is useful for player too
                                # check request items
                                items_n1_request = [ent['resource'] for ent in row_n1['request']]
                                items_n1_request = [ent.lower().replace(' ', '_') for ent in items_n1_request]
                                items_n1_request_amt = [ent['amount'] for ent in row_n1['request']]
                                items_n1_request_dict = {item: amt for item, amt in zip(
                                    items_n1_request, items_n1_request_amt)}
                                player_profession = player_profession_dict[filename][player]
                                player_useful_items = profession_items_dict[player_profession]
                                received_useful_items_list = [item for item in items_n1_request if item in player_useful_items]
                                print(items_n1_request_dict)
                                print(player_useful_items)
                                print('j = ', j, 'received_useful_items: ', received_useful_items_list)
                                if len(received_useful_items_list):
                                    score_gain = 0
                                    for item in received_useful_items_list:
                                        if item in itemTierValue_dict:
                                            score_gain += (items_n1_request_dict[item]*itemTierValue_dict[item]['value'])
                                        else:
                                            # unable to find this item in the tier value directory
                                            print('unable to find tier value for item: ', item)
                                    print('3-WAY TRADE! ', i,j)
                                    three_way_trades_dict[filename].append(
                                        {'player': player, 'trade1': i+1, 'trade2': i+j+1, 'count': j,
                                         'non_useful_items1': p2_non_useful, 'non_useful_items2': traded_nonuseful_items_list,
                                         'received_useful_items': items_n1_request_dict, 'score_gain': score_gain,
                                         'game_type': row_n1['game_type'],  'game_name': row_n1['game_name'],
                                         'trade1_ind': x_df.index[i], 'trade2_ind': x_df.index[i+j]})
                        elif row_n1['requested'] == player:
                            # check request items
                            items_n1 = [ent['resource'] for ent in row_n1['request']]
                            items_n1 = [ent.lower().replace(' ', '_') for ent in items_n1]
                            # within items in request, check if at least 1 item is from previous non_useful
                            traded_nonuseful_items_list = [item for item in items_n1 if item in p2_non_useful]
                            if len(traded_nonuseful_items_list):
                                # 3-way trade occured
                                # check if the item received is useful for player too
                                # check request items
                                items_n1_request = [ent['resource'] for ent in row_n1['offer']]
                                items_n1_request = [ent.lower().replace(' ', '_') for ent in items_n1_request]
                                items_n1_request_amt = [ent['amount'] for ent in row_n1['offer']]
                                items_n1_request_dict = {item: amt for item, amt in zip(
                                    items_n1_request, items_n1_request_amt)}
                                player_profession = player_profession_dict[filename][player]
                                player_useful_items = profession_items_dict[player_profession]
                                received_useful_items_list = [item for item in items_n1_request if item in player_useful_items]
                                print(items_n1_request_dict)
                                print(player_useful_items)
                                print('j = ', j, 'received_useful_items: ', received_useful_items_list)
                                if len(received_useful_items_list):
                                    score_gain = 0
                                    for item in received_useful_items_list:
                                        if item in itemTierValue_dict:
                                            score_gain += (items_n1_request_dict[item]*itemTierValue_dict[item]['value'])
                                        else:
                                            # use exp.xlsx
                                            if item in tier1_items_list:
                                                score_gain += (items_n1_request_dict[item] * TIER1_VALUE)
                                            elif item in tier2_items_list:
                                                score_gain += (items_n1_request_dict[item] * TIER2_VALUE)
                                            elif item in tier3_items_list:
                                                score_gain += (items_n1_request_dict[item] * TIER3_VALUE)
                                            else:
                                                # unable to find this item in the tier value directory
                                                print('unable to find tier value for item: ', item)
                                    print('3-WAY TRADE! ', i,j)
                                    three_way_trades_dict[filename].append(
                                        {'player': player, 'trade1': i+1, 'trade2': i+j+1, 'count': j,
                                         'non_useful_items1': p2_non_useful, 'non_useful_items2': traded_nonuseful_items_list,
                                         'received_useful_items': items_n1_request_dict, 'score_gain': score_gain,
                                         'game_type': row_n1['game_type'],  'game_name': row_n1['game_name'],
                                         'trade1_ind': x_df.index[i], 'trade2_ind': x_df.index[i+j]})
# Out:
# GeminiBase1
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiBase16
# Alex
# {'tropical_fish': 2}
# ['cod', 'salmon', 'tropical_fish', 'pufferfish', 'turtle_egg', 'oak_boat']
# j =  4 received_useful_items:  ['tropical_fish']
# 3-WAY TRADE!  0 4
# Cosmo
# Negan
# Sokka
# Steve
# GeminiBase18
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiBase2
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiBase3
# Alex
# Cosmo
# {'porkchop': 6}
# ['oak_log', 'spruce_log', 'birch_log', 'spruce_planks', 'oak_planks', 'diamond_axe']
# j =  4 received_useful_items:  []
# {'oak_planks': 1}
# ['oak_log', 'spruce_log', 'birch_log', 'spruce_planks', 'oak_planks', 'diamond_axe']
# j =  5 received_useful_items:  ['oak_planks']
# 3-WAY TRADE!  0 5
# {'porkchop': 6}
# ['oak_log', 'spruce_log', 'birch_log', 'spruce_planks', 'oak_planks', 'diamond_axe']
# j =  1 received_useful_items:  []
# {'oak_planks': 1}
# ['oak_log', 'spruce_log', 'birch_log', 'spruce_planks', 'oak_planks', 'diamond_axe']
# j =  2 received_useful_items:  ['oak_planks']
# 3-WAY TRADE!  3 2
# Negan
# Sokka
# Steve
# GeminiBase4
# Alex
# Cosmo
# {'red_glazed_terracotta': 1, 'blue_glazed_terracotta': 1}
# ['stone', 'quartz_block', 'glass', 'red_glazed_terracotta', 'blue_glazed_terracotta', 'stone_pickaxe']
# j =  1 received_useful_items:  ['red_glazed_terracotta', 'blue_glazed_terracotta']
# 3-WAY TRADE!  0 1
# Negan
# Sokka
# Steve
# {'iron_ingot': 2, 'gold_ingot': 2}
# ['iron_ingot', 'gold_ingot', 'coal', 'fletching_table', 'smithing_table', 'diamond_sword']
# j =  1 received_useful_items:  ['iron_ingot', 'gold_ingot']
# 3-WAY TRADE!  1 1
# GeminiBase5
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiBase8
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiComp1
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiComp2
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiComp3
# Alex
# Cosmo
# Negan
# {'turtle_egg': 1}
# ['cod', 'salmon', 'tropical_fish', 'pufferfish', 'turtle_egg', 'oak_boat']
# j =  2 received_useful_items:  ['turtle_egg']
# 3-WAY TRADE!  1 2
# Sokka
# Steve
# GeminiComp4
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiComp6
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# {'stick': 4}
# ['cod', 'salmon', 'tropical_fish', 'pufferfish', 'turtle_egg', 'oak_boat']
# j =  1 received_useful_items:  []
# GeminiComp7
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiComp8
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiComp9
# Alex
# Cosmo
# Negan
# {'coal': 1}
# ['iron_ingot', 'gold_ingot', 'coal', 'fletching_table', 'smithing_table', 'diamond_sword']
# j =  3 received_useful_items:  ['coal']
# 3-WAY TRADE!  2 3
# Sokka
# Steve
# GeminiCoop1
# Alex
# Cosmo
# {'bread': 2, 'pumpkin': 2}
# ['potato', 'carrot', 'wheat', 'bread', 'pumpkin', 'mushroom_stew']
# j =  7 received_useful_items:  ['bread', 'pumpkin']
# 3-WAY TRADE!  0 7
# {'bread': 2, 'pumpkin': 2}
# ['potato', 'carrot', 'wheat', 'bread', 'pumpkin', 'mushroom_stew']
# j =  6 received_useful_items:  ['bread', 'pumpkin']
# 3-WAY TRADE!  1 6
# {'bread': 2, 'pumpkin': 2}
# ['potato', 'carrot', 'wheat', 'bread', 'pumpkin', 'mushroom_stew']
# j =  1 received_useful_items:  ['bread', 'pumpkin']
# 3-WAY TRADE!  6 1
# Negan
# Sokka
# Steve
# {'rabbit_stew': 1}
# ['beef', 'chicken', 'porkchop', 'cooked_beef', 'cooked_porkchop', 'rabbit_stew']
# j =  1 received_useful_items:  ['rabbit_stew']
# 3-WAY TRADE!  1 1
# GeminiCoop3
# Alex
# Cosmo
# Negan
# {'lead': 2}
# ['leather', 'stick', 'lead', 'cow_spawn_egg', 'rabbit_hide', 'saddle']
# j =  1 received_useful_items:  ['lead']
# 3-WAY TRADE!  0 1
# {'saddle': 1}
# ['leather', 'stick', 'lead', 'cow_spawn_egg', 'rabbit_hide', 'saddle']
# j =  3 received_useful_items:  ['saddle']
# 3-WAY TRADE!  0 3
# {'saddle': 1}
# ['leather', 'stick', 'lead', 'cow_spawn_egg', 'rabbit_hide', 'saddle']
# j =  1 received_useful_items:  ['saddle']
# 3-WAY TRADE!  2 1
# Sokka
# Steve
# {'stone': 4}
# ['stone', 'quartz_block', 'glass', 'red_glazed_terracotta', 'blue_glazed_terracotta', 'stone_pickaxe']
# j =  1 received_useful_items:  ['stone']
# 3-WAY TRADE!  0 1
# GeminiCoop4
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiCoop5
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiCoop6
# Alex
# {'cooked_beef': 4, 'cooked_porkchop': 4}
# ['beef', 'chicken', 'porkchop', 'cooked_beef', 'cooked_porkchop', 'rabbit_stew']
# j =  1 received_useful_items:  ['cooked_beef', 'cooked_porkchop']
# 3-WAY TRADE!  0 1
# Cosmo
# Negan
# Sokka
# Steve
# {'salmon': 2, 'tropical_fish': 3}
# ['cod', 'salmon', 'tropical_fish', 'pufferfish', 'turtle_egg', 'oak_boat']
# j =  3 received_useful_items:  ['salmon', 'tropical_fish']
# 3-WAY TRADE!  0 3
# GeminiCoop7
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiCoop8
# Alex
# Cosmo
# Negan
# Sokka
# Steve
# GeminiCoop9
# Alex
# Cosmo
# Negan
# Sokka
# Steve

# %%
# three_way_trades_dict = {}

# for filename in game_trades_df_dict:
#     print(filename)
#     three_way_trades_dict[filename] = {}
#     trades_df = game_trades_df_dict[filename]
#     trades_df = get_request_non_useful_items(trades_df, player_names_list, player_profession_dict, profession_items_dict, filename)
    
#     for player in player_names_list:
#         three_way_trades_dict[filename][player] = []
#     #     player_profession = player_profession_dict[filename][player]
#     #     player_useful_items = profession_items_dict[player_profession]
#         x_df = trades_df[(trades_df['requester']==player) | (trades_df['requested']==player)]
#         # each player participated accepted trades
#     #     for ind, row in player_trades_df:
#     #         if row['requester'] == player:
#     #             # player is requester, need to check request items
#     #             request_list = row['request']
#     #             request_items_list = [ent['resource'].lower().replace(' ', '_') for ent in request_list]
#     #             request_non_useful_items_list = [item for item in request_items_list if item not in player_useful_items]
#     #             if len(request_non_useful_items_list):
#     #                 flag = 1

#         for i in range(len(x_df.index)-1):
#             row = x_df.loc[x_df.index[i], :]
#             p1 = row['requester']
#             p2 = row['requested']
#             if p1 == player:
#                 # check requester_nonuseful
#                 p1_non_useful = row['requester_nonuseful']
#                 # p2_non_useful = row['requested_nonuseful']
#                 if len(p1_non_useful):
#                     # p1 got non-useful items
#                     # does he trade these items in the next 2 trades
#                     row_n1 = x_df.loc[x_df.index[i+1], :]
#                     if row_n1['requester'] == player:
#                         # check offer items
#                         items_n1 = [ent['resource'] for ent in row_n1['offer']]
#                         items_n1 = [ent.lower().replace(' ', '_') for ent in items_n1]
#                         # within items in offer, check if at least 1 item is from previous non_useful
#                         traded_nonuseful_items_list = [item for item in items_n1 if item in p1_non_useful]
#                         if len(traded_nonuseful_items_list):
#                             # 3-way trade occured
#                             three_way_trades_dict[filename][player].append({'trade1': x_df.index[i], 'trade2': x_df.index[i+1]})
#                     elif row_n1['requested'] == player:
#                         # check request items
#                         items_n1 = [ent['resource'] for ent in row_n1['request']]
#                         items_n1 = [ent.lower().replace(' ', '_') for ent in items_n1]
#                         # within items in request, check if at least 1 item is from previous non_useful
#                         traded_nonuseful_items_list = [item for item in items_n1 if item in p1_non_useful]
#                         if len(traded_nonuseful_items_list):
#                             # 3-way trade occured
#                             three_way_trades_dict[filename][player].append({'trade1': x_df.index[i], 'trade2': x_df.index[i+1]})
                        
#                     if i != len(x_df.index)-2:
#                         row_n2 = x_df.loc[x_df.index[i+2], :]
#                         if row_n2['requester'] == player:
#                             # check offer items
#                             items_n2 = [ent['resource'] for ent in row_n2['offer']]
#                             items_n2 = [ent.lower().replace(' ', '_') for ent in items_n2]
#                             # within items in offer, check if at least 1 item is from previous non_useful
#                             traded_nonuseful_items_list = [item for item in items_n2 if item in p1_non_useful]
#                             if len(traded_nonuseful_items_list):
#                                 # 3-way trade occured
#                                 three_way_trades_dict[filename][player].append({'trade1': x_df.index[i], 'trade2': x_df.index[i+2]})
#                         elif row_n2['requested'] == player:
#                             # check request items
#                             items_n2 = [ent['resource'] for ent in row_n2['request']]
#                             items_n2 = [ent.lower().replace(' ', '_') for ent in items_n2]
#                             # within items in request, check if at least 1 item is from previous non_useful
#                             traded_nonuseful_items_list = [item for item in items_n2 if item in p1_non_useful]
#                             if len(traded_nonuseful_items_list):
#                                 # 3-way trade occured
#                                 three_way_trades_dict[filename][player].append({'trade1': x_df.index[i], 'trade2': x_df.index[i+2]})
#             if p2 == player:
#                 # check requested_nonuseful
#                 # p1_non_useful = row['requester_nonuseful']
#                 p2_non_useful = row['requested_nonuseful']
#                 if len(p2_non_useful):
#                     # p2 got non-useful items
#                     # does he trade these items in the next 2 trades
#                     row_n1 = x_df.loc[x_df.index[i+1], :]
#                     if row_n1['requester'] == player:
#                         # check offer items
#                         items_n1 = [ent['resource'] for ent in row_n1['offer']]
#                         items_n1 = [ent.lower().replace(' ', '_') for ent in items_n1]
#                         # within items in offer, check if at least 1 item is from previous non_useful
#                         traded_nonuseful_items_list = [item for item in items_n1 if item in p2_non_useful]
#                         if len(traded_nonuseful_items_list):
#                             # 3-way trade occured
#                             three_way_trades_dict[filename][player].append({'trade1': x_df.index[i], 'trade2': x_df.index[i+1]})
#                     elif row_n1['requested'] == player:
#                         # check request items
#                         items_n1 = [ent['resource'] for ent in row_n1['request']]
#                         items_n1 = [ent.lower().replace(' ', '_') for ent in items_n1]
#                         # within items in request, check if at least 1 item is from previous non_useful
#                         traded_nonuseful_items_list = [item for item in items_n1 if item in p2_non_useful]
#                         if len(traded_nonuseful_items_list):
#                             # 3-way trade occured
#                             three_way_trades_dict[filename][player].append({'trade1': x_df.index[i], 'trade2': x_df.index[i+1]})
                        
#                     if i != len(x_df.index)-2:
#                         row_n2 = x_df.loc[x_df.index[i+2], :]
#                         if row_n2['requester'] == player:
#                             # check offer items
#                             items_n2 = [ent['resource'] for ent in row_n2['offer']]
#                             items_n2 = [ent.lower().replace(' ', '_') for ent in items_n2]
#                             # within items in offer, check if at least 1 item is from previous non_useful
#                             traded_nonuseful_items_list = [item for item in items_n2 if item in p2_non_useful]
#                             if len(traded_nonuseful_items_list):
#                                 # 3-way trade occured
#                                 three_way_trades_dict[filename][player].append({'trade1': x_df.index[i], 'trade2': x_df.index[i+2]})
#                         elif row_n2['requested'] == player:
#                             # check request items
#                             items_n2 = [ent['resource'] for ent in row_n2['request']]
#                             items_n2 = [ent.lower().replace(' ', '_') for ent in items_n2]
#                             # within items in request, check if at least 1 item is from previous non_useful
#                             traded_nonuseful_items_list = [item for item in items_n2 if item in p2_non_useful]
#                             if len(traded_nonuseful_items_list):
#                                 # 3-way trade occured
#                                 three_way_trades_dict[filename][player].append({'trade1': x_df.index[i], 'trade2': x_df.index[i+2]})

# %%
three_way_trades_dict
# Out:
# {'GeminiBase1': [],
#  'GeminiBase16': [{'player': 'Alex',
#    'trade1': 1,
#    'trade2': 5,
#    'count': 4,
#    'non_useful_items1': ['coal'],
#    'non_useful_items2': ['coal'],
#    'received_useful_items': {'tropical_fish': 2},
#    'score_gain': 2,
#    'game_type': 'Baseline',
#    'game_name': '16',
#    'trade1_ind': 1,
#    'trade2_ind': 30}],
#  'GeminiBase18': [],
#  'GeminiBase2': [],
#  'GeminiBase3': [{'player': 'Cosmo',
#    'trade1': 1,
#    'trade2': 6,
#    'count': 5,
#    'non_useful_items1': ['cooked_beef', 'cooked_porkchop'],
#    'non_useful_items2': ['cooked_beef'],
#    'received_useful_items': {'oak_planks': 1},
#    'score_gain': 3,
#    'game_type': 'Baseline',
#    'game_name': '3',
#    'trade1_ind': 0,
#    'trade2_ind': 20},
#   {'player': 'Cosmo',
#    'trade1': 4,
#    'trade2': 6,
#    'count': 2,
#    'non_useful_items1': ['cooked_beef'],
#    'non_useful_items2': ['cooked_beef'],
#    'received_useful_items': {'oak_planks': 1},
#    'score_gain': 3,
#    'game_type': 'Baseline',
#    'game_name': '3',
#    'trade1_ind': 6,
#    'trade2_ind': 20}],
#  'GeminiBase4': [{'player': 'Cosmo',
#    'trade1': 1,
#    'trade2': 2,
#    'count': 1,
#    'non_useful_items1': ['loom'],
#    'non_useful_items2': ['loom', 'loom'],
#    'received_useful_items': {'red_glazed_terracotta': 1,
#     'blue_glazed_terracotta': 1},
#    'score_gain': 6,
#    'game_type': 'Baseline',
#    'game_name': '4',
#    'trade1_ind': 12,
#    'trade2_ind': 14},
#   {'player': 'Steve',
#    'trade1': 2,
#    'trade2': 3,
#    'count': 1,
#    'non_useful_items1': ['string'],
#    'non_useful_items2': ['string'],
#    'received_useful_items': {'iron_ingot': 2, 'gold_ingot': 2},
#    'score_gain': 4,
#    'game_type': 'Baseline',
#    'game_name': '4',
#    'trade1_ind': 2,
#    'trade2_ind': 10}],
#  'GeminiBase5': [],
#  'GeminiBase8': [],
#  'GeminiComp1': [],
#  'GeminiComp2': [],
#  'GeminiComp3': [{'player': 'Negan',
#    'trade1': 2,
#    'trade2': 4,
#    'count': 2,
#    'non_useful_items1': ['coal', 'sheep_spawn_egg'],
#    'non_useful_items2': ['sheep_spawn_egg'],
#    'received_useful_items': {'turtle_egg': 1},
#    'score_gain': 3,
#    'game_type': 'Competitive',
#    'game_name': '3',
#    'trade1_ind': 4,
#    'trade2_ind': 8}],
#  'GeminiComp4': [],
#  'GeminiComp6': [],
#  'GeminiComp7': [],
#  'GeminiComp8': [],
#  'GeminiComp9': [{'player': 'Negan',
#    'trade1': 3,
#    'trade2': 6,
#    'count': 3,
#    'non_useful_items1': ['birch_log'],
#    'non_useful_items2': ['birch_log'],
#    'received_useful_items': {'coal': 1},
#    'score_gain': 1,
#    'game_type': 'Competitive',
#    'game_name': '9',
#    'trade1_ind': 9,
#    'trade2_ind': 27}],
#  'GeminiCoop1': [{'player': 'Cosmo',
#    'trade1': 1,
#    'trade2': 8,
#    'count': 7,
#    'non_useful_items1': ['rabbit_hide'],
#    'non_useful_items2': ['rabbit_hide'],
#    'received_useful_items': {'bread': 2, 'pumpkin': 2},
#    'score_gain': 12,
#    'game_type': 'Cooperative',
#    'game_name': '1',
#    'trade1_ind': 4,
#    'trade2_ind': 17},
#   {'player': 'Cosmo',
#    'trade1': 2,
#    'trade2': 8,
#    'count': 6,
#    'non_useful_items1': ['saddle'],
#    'non_useful_items2': ['saddle'],
#    'received_useful_items': {'bread': 2, 'pumpkin': 2},
#    'score_gain': 12,
#    'game_type': 'Cooperative',
#    'game_name': '1',
#    'trade1_ind': 7,
#    'trade2_ind': 17},
#   {'player': 'Cosmo',
#    'trade1': 7,
#    'trade2': 8,
#    'count': 1,
#    'non_useful_items1': ['saddle'],
#    'non_useful_items2': ['saddle'],
#    'received_useful_items': {'bread': 2, 'pumpkin': 2},
#    'score_gain': 12,
#    'game_type': 'Cooperative',
#    'game_name': '1',
#    'trade1_ind': 16,
#    'trade2_ind': 17},
#   {'player': 'Steve',
#    'trade1': 2,
#    'trade2': 3,
#    'count': 1,
#    'non_useful_items1': ['saddle'],
#    'non_useful_items2': ['saddle'],
#    'received_useful_items': {'rabbit_stew': 1},
#    'score_gain': 10,
#    'game_type': 'Cooperative',
#    'game_name': '1',
#    'trade1_ind': 13,
#    'trade2_ind': 16}],
#  'GeminiCoop3': [{'player': 'Negan',
#    'trade1': 1,
#    'trade2': 2,
#    'count': 1,
#    'non_useful_items1': ['potato', 'carrot'],
#    'non_useful_items2': ['carrot'],
#    'received_useful_items': {'lead': 2},
#    'score_gain': 2,
#    'game_type': 'Cooperative',
#    'game_name': '3',
#    'trade1_ind': 2,
#    'trade2_ind': 3},
#   {'player': 'Negan',
#    'trade1': 1,
#    'trade2': 4,
#    'count': 3,
#    'non_useful_items1': ['potato', 'carrot'],
#    'non_useful_items2': ['potato'],
#    'received_useful_items': {'saddle': 1},
#    'score_gain': 10,
#    'game_type': 'Cooperative',
#    'game_name': '3',
#    'trade1_ind': 2,
#    'trade2_ind': 8},
#   {'player': 'Negan',
#    'trade1': 3,
#    'trade2': 4,
#    'count': 1,
#    'non_useful_items1': ['potato'],
#    'non_useful_items2': ['potato'],
#    'received_useful_items': {'saddle': 1},
#    'score_gain': 10,
#    'game_type': 'Cooperative',
#    'game_name': '3',
#    'trade1_ind': 6,
#    'trade2_ind': 8},
#   {'player': 'Steve',
#    'trade1': 1,
#    'trade2': 2,
#    'count': 1,
#    'non_useful_items1': ['carrot'],
#    'non_useful_items2': ['carrot'],
#    'received_useful_items': {'stone': 4},
#    'score_gain': 4,
#    'game_type': 'Cooperative',
#    'game_name': '3',
#    'trade1_ind': 3,
#    'trade2_ind': 11}],
#  'GeminiCoop4': [],
#  'GeminiCoop5': [],
#  'GeminiCoop6': [{'player': 'Alex',
#    'trade1': 1,
#    'trade2': 2,
#    'count': 1,
#    'non_useful_items1': ['leather', 'stick'],
#    'non_useful_items2': ['leather'],
#    'received_useful_items': {'cooked_beef': 4, 'cooked_porkchop': 4},
#    'score_gain': 24,
#    'game_type': 'Cooperative',
#    'game_name': '6',
#    'trade1_ind': 0,
#    'trade2_ind': 3},
#   {'player': 'Steve',
#    'trade1': 1,
#    'trade2': 4,
#    'count': 3,
#    'non_useful_items1': ['oak_log'],
#    'non_useful_items2': ['oak_log', 'oak_log'],
#    'received_useful_items': {'salmon': 2, 'tropical_fish': 3},
#    'score_gain': 5,
#    'game_type': 'Cooperative',
#    'game_name': '6',
#    'trade1_ind': 4,
#    'trade2_ind': 17}],
#  'GeminiCoop7': [],
#  'GeminiCoop8': [],
#  'GeminiCoop9': []}

# %%
three_way_trades_df_dict = {filename: df.from_records(three_way_trades_dict[filename]) for filename in three_way_trades_dict if three_way_trades_dict[filename] != []}
three_way_trades_df_dict.keys()
# Out:
# dict_keys(['GeminiBase16', 'GeminiBase3', 'GeminiBase4', 'GeminiComp3', 'GeminiComp9', 'GeminiCoop1', 'GeminiCoop3', 'GeminiCoop6'])

# %%
master_three_way_trades_df = df(columns=three_way_trades_df_dict['GeminiCoop3'].columns)
print(master_three_way_trades_df.shape)
for filename in three_way_trades_df_dict:
    master_three_way_trades_df = pd.concat([master_three_way_trades_df, three_way_trades_df_dict[filename]])
    print(filename, three_way_trades_df_dict[filename].shape, master_three_way_trades_df.shape)    
master_three_way_trades_df
# Out:
# (0, 12)
# GeminiBase16 (1, 12) (1, 12)
# GeminiBase3 (2, 12) (3, 12)
# GeminiBase4 (2, 12) (5, 12)
# GeminiComp3 (1, 12) (6, 12)
# GeminiComp9 (1, 12) (7, 12)
# GeminiCoop1 (4, 12) (11, 12)
# GeminiCoop3 (4, 12) (15, 12)
# GeminiCoop6 (2, 12) (17, 12)
#   player trade1 trade2 count               non_useful_items1  \
# 0   Alex      1      5     4                          [coal]
# 0  Cosmo      1      6     5  [cooked_beef, cooked_porkchop]
# 1  Cosmo      4      6     2                   [cooked_beef]
# 0  Cosmo      1      2     1                          [loom]
# 1  Steve      2      3     1                        [string]
# 0  Negan      2      4     2         [coal, sheep_spawn_egg]
# 0  Negan      3      6     3                     [birch_log]
# 0  Cosmo      1      8     7                   [rabbit_hide]
# 1  Cosmo      2      8     6                        [saddle]
# 2  Cosmo      7      8     1                        [saddle]
# 3  Steve      2      3     1                        [saddle]
# 0  Negan      1      2     1                [potato, carrot]
# 1  Negan      1      4     3                [potato, carrot]
# 2  Negan      3      4     1                        [potato]
# 3  Steve      1      2     1                        [carrot]
# 0   Alex      1      2     1                [leather, stick]
# 1  Steve      1      4     3                       [oak_log]
#
#     non_useful_items2                              received_useful_items  \
# 0              [coal]                               {'tropical_fish': 2}
# 0       [cooked_beef]                                  {'oak_planks': 1}
# 1       [cooked_beef]                                  {'oak_planks': 1}
# 0        [loom, loom]  {'red_glazed_terracotta': 1, 'blue_glazed_terr...
# 1            [string]                 {'iron_ingot': 2, 'gold_ingot': 2}
# 0   [sheep_spawn_egg]                                  {'turtle_egg': 1}
# 0         [birch_log]                                        {'coal': 1}
# 0       [rabbit_hide]                         {'bread': 2, 'pumpkin': 2}
# 1            [saddle]                         {'bread': 2, 'pumpkin': 2}
# 2            [saddle]                         {'bread': 2, 'pumpkin': 2}
# 3            [saddle]                                 {'rabbit_stew': 1}
# 0            [carrot]                                        {'lead': 2}
# 1            [potato]                                      {'saddle': 1}
# 2            [potato]                                      {'saddle': 1}
# 3            [carrot]                                       {'stone': 4}
# 0           [leather]           {'cooked_beef': 4, 'cooked_porkchop': 4}
# 1  [oak_log, oak_log]                  {'salmon': 2, 'tropical_fish': 3}
#
#   score_gain    game_type game_name trade1_ind trade2_ind
# 0          2     Baseline        16          1         30
# 0          3     Baseline         3          0         20
# 1          3     Baseline         3          6         20
# 0          6     Baseline         4         12         14
# 1          4     Baseline         4          2         10
# 0          3  Competitive         3          4          8
# 0          1  Competitive         9          9         27
# 0         12  Cooperative         1          4         17
# 1         12  Cooperative         1          7         17
# 2         12  Cooperative         1         16         17
# 3         10  Cooperative         1         13         16
# 0          2  Cooperative         3          2          3
# 1         10  Cooperative         3          2          8
# 2         10  Cooperative         3          6          8
# 3          4  Cooperative         3          3         11
# 0         24  Cooperative         6          0          3
# 1          5  Cooperative         6          4         17

# %%
# master_three_way_trades_df.to_excel('geminiAgents-ArbitrageTrades-Counter-df.xlsx')

# %%
master_three_way_trades_df['count'].hist()
# Out:
# <AxesSubplot:>

# %%
master_three_way_trades_df['count'].mean(), master_three_way_trades_df['count'].median()
# Out:
# (2.5294117647058822, 2.0)

# %% [markdown]
# #### HOARDING TASK 2

# %%
hoarded_items_dict = {}

for filename in game_trades_df_dict:
    print(filename)
    hoarded_items_dict[filename] = []
    # three_way_trades_dict[filename] = []
    trades_df = game_trades_df_dict[filename]
    player_names_list = list(set(player_profession_dict[filename].keys()))
    trades_df = get_request_non_useful_items(trades_df, player_names_list, player_profession_dict, profession_items_dict, filename)
    # print(trades_df.columns)

    if ('requestedInventory' not in trades_df.columns) or ('requestedInventory' not in trades_df.columns):
        print('no requestedInventory/requesterInventory')
        continue
        
    for player in player_names_list:
        player_profession = player_profession_dict[filename][player]
        player_useful_items = profession_items_dict[player_profession]
        x_df = trades_df[(trades_df['requester']==player) | (trades_df['requested']==player)]
        print(player, x_df.shape)
        if x_df.shape[0] < 1:
            continue
        row1 = x_df.iloc[0, :]
        p1 = row1['requester']
        p2 = row1['requested']
        if p1 == player:
            # first trade as requester, check requesterInventory
            player_inventory1 = row1['requesterInventory']
        else:
            # first trade as requested, check requestedInventory
            player_inventory1 = row1['requestedInventory']
        
        row2 = x_df.iloc[-1,:]
        p1 = row2['requester']
        p2 = row2['requested']
        if p1 == player:
            # first trade as requester, check requesterInventory
            player_inventory2 = row2['requesterInventory']
        else:
            # first trade as requested, check requestedInventory
            player_inventory2 = row2['requestedInventory']

        player_start_inventory_dict = {}
        for ent in player_inventory1:
            if ent['resource'] not in player_start_inventory_dict:
                player_start_inventory_dict[ent['resource'].lower().replace(' ', '_')] = 0
            player_start_inventory_dict[ent['resource'].lower().replace(' ', '_')] += ent['amount']

        player_end_inventory_dict = {}
        for ent in player_inventory2:
            if ent['resource'] not in player_end_inventory_dict:
                player_end_inventory_dict[ent['resource'].lower().replace(' ', '_')] = 0
            player_end_inventory_dict[ent['resource'].lower().replace(' ', '_')] += ent['amount']

        total_items_list = list(set(player_start_inventory_dict.keys()) | set(player_end_inventory_dict.keys()))
        total_items_list = [item.lower().replace(' ', '_') for item in total_items_list]
        nonuseful_items_list = [item for item in total_items_list if item not in player_useful_items]
        nonuseful_items_list = [item for item in nonuseful_items_list if (
            item in itemTierValue_dict)]
        print('nonuseful_items = ', nonuseful_items_list)

#         num_trades = 0
#         for ind, row in x_df.iterrows():
#             p1 = row['requester']
#             p2 = row['requested']
#             if p1 == player:
#                 # first trade as requester, check requesterInventory
#                 player_nonuseful = row['requester_nonuseful']
#             if p2 == player:
#                 # first trade as requester, check requesterInventory
#                 player_nonuseful = row['requested_nonuseful']
#             if player_nonuseful != []:
#                 # some nonuseful item in trade
#                 hoarding_list = [item for item in player_nonuseful if item in nonuseful_items_list]
#                 if hoarding_list != []:
#                     # hoarding exists, add this trade into count
#                     num_trades += 1
        
        hoarded_items_list = []
        hoarded_score = 0
        for item in nonuseful_items_list:
            dct = {}
            # print(item in 
            if item in player_end_inventory_dict:
                print(item, ' end ', player_end_inventory_dict[item])
                if item not in dct:
                    dct = {item: 0}
                dct[item] += player_end_inventory_dict[item]
                if item in player_start_inventory_dict:
                    dct[item] -= player_start_inventory_dict[item]
                    print(item, ' start ', player_start_inventory_dict[item])    
                if dct[item] > 0:
                    if item in itemTierValue_dict:
                        hoarded_score += (dct[item]*itemTierValue_dict[item]['value'])
                    else:
                        # use exp.xlsx
                        if item in tier1_items_list:
                            hoarded_score += (dct[item] * TIER1_VALUE)
                        elif item in tier2_items_list:
                            hoarded_score += (dct[item] * TIER2_VALUE)
                        elif item in tier3_items_list:
                            hoarded_score += (dct[item] * TIER3_VALUE)
                        else:
                            # unable to find this item in the tier value directory
                            print('unable to find tier value for item: ', item)
                if dct[item] > 0:
                    hoarded_items_list.append(dct)
        num_trades = 0
        hoarded_score_2 = 0
        ls = [list(ent.keys())[0] for ent in hoarded_items_list]
        hoarded_items_list_2 = {}
        for ind, row in x_df.iterrows():
            p1 = row['requester']
            p2 = row['requested']
            if p1 == player:
                # first trade as requester, check requesterInventory
                player_nonuseful = row['requester_nonuseful']
                player_receiving_items_dict = {ent['resource'].lower().replace(' ', '_'): ent['amount'] for ent in row['request']}
                player_receiving_items_list = [ent['resource'].lower().replace(' ', '_') for ent in row['request']]
                print(ind, player_nonuseful, player_receiving_items_dict)
            if p2 == player:
                # first trade as requester, check requesterInventory
                player_nonuseful = row['requested_nonuseful']
                player_receiving_items_dict = {ent['resource'].lower().replace(' ', '_'): ent['amount'] for ent in row['offer']}
                player_receiving_items_list = [ent['resource'].lower().replace(' ', '_') for ent in row['offer']]
                print(ind, player_nonuseful, player_receiving_items_dict)
            if player_nonuseful != []:
                # some nonuseful item in trade
                hoarding_list = [item for item in player_nonuseful if item in ls]
                if hoarding_list != []:
                    # hoarding exists, add this trade into count
                    print('hoarding_list: ', hoarding_list)
                    if set(player_nonuseful) == set(player_receiving_items_list):
                        num_trades += 1
                        print('num_trades = ', num_trades)
                        for item in player_receiving_items_dict:
                            if item not in hoarded_items_list_2:
                                hoarded_items_list_2[item] = 0                                
                            if item in itemTierValue_dict:
                                hoarded_score_2 += (player_receiving_items_dict[item]*itemTierValue_dict[item]['value'])
                                hoarded_items_list_2[item] += player_receiving_items_dict[item]
                            else:
                                # use exp.xlsx
                                if item in tier1_items_list:
                                    hoarded_score_2 += (player_receiving_items_dict[item] * TIER1_VALUE)
                                    hoarded_items_list_2[item] += player_receiving_items_dict[item]
                                elif item in tier2_items_list:
                                    hoarded_score_2 += (player_receiving_items_dict[item] * TIER2_VALUE)
                                    hoarded_items_list_2[item] += player_receiving_items_dict[item]
                                elif item in tier3_items_list:
                                    hoarded_score_2 += (dct[item] * TIER3_VALUE)
                                    hoarded_items_list_2[item] += player_receiving_items_dict[item]
                                else:
                                    # unable to find this item in the tier value directory
                                    print('unable to find tier value for item: ', item)
        if hoarded_score_2 < hoarded_score:
            hoarded_score = hoarded_score_2
            hoarded_items_list = hoarded_items_list_2

        if hoarded_score != 0:
            hoarded_items_dict[filename].append(
                {'player': player, 'items_list': hoarded_items_list, 'hoarded_score': hoarded_score,
                 'num_trades': num_trades, 'game_type': row1['game_type'],  'game_name': row1['game_name']})
# Out:
# GeminiBase1
# Steve (1, 19)
# nonuseful_items =  ['smithing_table', 'bread', 'fletching_table', 'iron_ingot', 'carrot', 'cow_spawn_egg', 'lead', 'leather', 'white_wool', 'shears']
# smithing_table  end  1
# smithing_table  start  1
# bread  end  1
# bread  start  1
# fletching_table  end  4
# fletching_table  start  4
# iron_ingot  end  4
# iron_ingot  start  4
# carrot  end  1
# carrot  start  1
# cow_spawn_egg  end  3
# cow_spawn_egg  start  3
# lead  end  3
# lead  start  3
# leather  end  1
# leather  start  1
# white_wool  end  3
# white_wool  start  3
# shears  end  1
# shears  start  1
# 25 ['iron_ingot'] {'iron_ingot': 10}
# Sokka (7, 19)
# nonuseful_items =  ['wheat', 'stick', 'blue_dye', 'glass', 'blue_glazed_terracotta', 'carrot', 'cow_spawn_egg', 'lead', 'stone_pickaxe', 'stone', 'red_glazed_terracotta', 'pumpkin', 'mushroom_stew']
# wheat  end  5
# wheat  start  5
# stick  end  10
# stick  start  10
# glass  end  9
# glass  start  9
# blue_glazed_terracotta  end  4
# blue_glazed_terracotta  start  4
# carrot  end  3
# carrot  start  3
# lead  end  1
# lead  start  1
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# stone  end  2
# stone  start  2
# red_glazed_terracotta  end  2
# red_glazed_terracotta  start  2
# pumpkin  end  5
# pumpkin  start  3
# mushroom_stew  end  1
# mushroom_stew  start  1
# 3 [] {'gold_ingot': 5}
# 4 [] {'diamond_sword': 1}
# 8 [] {'coal': 1}
# 9 ['pumpkin'] {'pumpkin': 1}
# hoarding_list:  ['pumpkin']
# num_trades =  1
# 11 ['pumpkin'] {'pumpkin': 2}
# hoarding_list:  ['pumpkin']
# num_trades =  2
# 21 [] {'fletching_table': 1}
# 25 [] {'fletching_table': 1}
# Negan (4, 19)
# nonuseful_items =  ['gold_ingot', 'string', 'blue_dye', 'bread', 'quartz_block', 'loom', 'white_wool', 'potato', 'red_glazed_terracotta', 'mushroom_stew']
# gold_ingot  end  5
# gold_ingot  start  10
# blue_dye  end  1
# blue_dye  start  1
# bread  end  4
# bread  start  5
# quartz_block  end  1
# quartz_block  start  1
# loom  end  8
# loom  start  8
# white_wool  end  6
# white_wool  start  6
# potato  end  12
# potato  start  12
# red_glazed_terracotta  end  2
# red_glazed_terracotta  start  2
# mushroom_stew  end  1
# mushroom_stew  start  1
# 3 [] {'cow_spawn_egg': 1}
# 7 [] {'lead': 1}
# 10 [] {'saddle': 1}
# 13 [] {'saddle': 1}
# Cosmo (7, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'stick', 'fletching_table', 'loom', 'leather', 'stone_pickaxe', 'saddle', 'smithing_table', 'string', 'rabbit_hide', 'glass', 'coal', 'cow_spawn_egg', 'lead', 'white_wool', 'shears', 'stone']
# gold_ingot  end  3
# gold_ingot  start  3
# diamond_sword  end  1
# diamond_sword  start  1
# stick  end  2
# stick  start  2
# fletching_table  end  1
# fletching_table  start  1
# loom  end  1
# loom  start  1
# leather  end  2
# leather  start  2
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# saddle  end  1
# saddle  start  2
# smithing_table  end  5
# smithing_table  start  5
# rabbit_hide  end  1
# rabbit_hide  start  1
# glass  end  11
# glass  start  11
# cow_spawn_egg  end  6
# cow_spawn_egg  start  6
# lead  end  9
# lead  start  9
# shears  end  1
# shears  start  1
# stone  end  1
# stone  start  1
# 2 [] {'wheat': 10, 'pumpkin': 2}
# 4 [] {'mushroom_stew': 1}
# 5 [] {'wheat': 4}
# 8 [] {'pumpkin': 1}
# 10 [] {'bread': 1}
# 18 ['diamond_sword'] {'diamond_sword': 1}
# 21 ['gold_ingot'] {'gold_ingot': 3}
# Alex (7, 19)
# nonuseful_items =  ['diamond_sword', 'wheat', 'bread', 'fletching_table', 'carrot', 'leather', 'saddle', 'pumpkin', 'smithing_table', 'rabbit_hide', 'coal', 'blue_glazed_terracotta', 'iron_ingot', 'lead', 'potato', 'stone']
# diamond_sword  end  1
# diamond_sword  start  1
# wheat  end  1
# wheat  start  15
# bread  end  1
# bread  start  1
# fletching_table  end  5
# fletching_table  start  5
# carrot  end  2
# carrot  start  2
# leather  end  12
# leather  start  12
# pumpkin  end  1
# pumpkin  start  6
# smithing_table  end  2
# smithing_table  start  2
# rabbit_hide  end  4
# rabbit_hide  start  4
# coal  end  19
# coal  start  19
# blue_glazed_terracotta  end  2
# blue_glazed_terracotta  start  2
# iron_ingot  end  1
# iron_ingot  start  1
# lead  end  6
# lead  start  7
# potato  end  1
# potato  start  1
# stone  end  7
# stone  start  7
# 2 [] {'white_wool': 1}
# 5 [] {'string': 7}
# 7 [] {'string': 13}
# 9 [] {'blue_dye': 1}
# 11 [] {'blue_dye': 2}
# 13 [] {'white_wool': 6}
# 18 [] {'white_wool': 5}
# GeminiBase16
# Steve (7, 19)
# nonuseful_items =  ['oak_planks', 'rabbit_hide', 'quartz_block', 'glass', 'tropical_fish', 'diamond_axe', 'oak_log', 'stone_pickaxe', 'stone', 'salmon', 'pufferfish']
# rabbit_hide  end  3
# rabbit_hide  start  3
# quartz_block  end  2
# quartz_block  start  2
# glass  end  19
# glass  start  19
# diamond_axe  end  1
# diamond_axe  start  1
# stone  end  7
# stone  start  7
# salmon  end  1
# salmon  start  1
# 0 [] {'smithing_table': 1}
# 1 [] {'fletching_table': 1}
# 2 [] {'diamond_sword': 1}
# 15 [] {'smithing_table': 1}
# 26 [] {'fletching_table': 1}
# 30 [] {'coal': 13}
# 36 [] {'diamond_sword': 1, 'iron_ingot': 1}
# Sokka (4, 19)
# nonuseful_items =  ['gold_ingot', 'stick', 'fletching_table', 'quartz_block', 'tropical_fish', 'oak_boat', 'cod', 'turtle_egg', 'leather', 'stone_pickaxe', 'saddle', 'smithing_table', 'coal', 'blue_glazed_terracotta', 'cow_spawn_egg', 'stone', 'salmon']
# gold_ingot  end  9
# gold_ingot  start  9
# stick  end  3
# stick  start  3
# fletching_table  end  1
# fletching_table  start  1
# quartz_block  end  5
# quartz_block  start  5
# tropical_fish  end  10
# tropical_fish  start  10
# oak_boat  end  1
# oak_boat  start  1
# cod  end  18
# cod  start  18
# turtle_egg  end  7
# turtle_egg  start  7
# leather  end  1
# leather  start  1
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# saddle  end  2
# saddle  start  2
# smithing_table  end  3
# smithing_table  start  5
# coal  end  2
# coal  start  2
# blue_glazed_terracotta  end  1
# blue_glazed_terracotta  start  1
# cow_spawn_egg  end  1
# cow_spawn_egg  start  1
# stone  end  1
# stone  start  1
# salmon  end  4
# salmon  start  4
# 0 [] {'oak_planks': 5}
# 15 [] {'oak_log': 1}
# 19 [] {'birch_log': 6}
# 21 [] {'oak_log': 5}
# Negan (4, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'stick', 'fletching_table', 'cod', 'birch_log', 'leather', 'saddle', 'spruce_log', 'smithing_table', 'rabbit_hide', 'iron_ingot', 'cow_spawn_egg', 'lead', 'oak_log', 'spruce_planks']
# gold_ingot  end  1
# gold_ingot  start  1
# diamond_sword  end  1
# diamond_sword  start  1
# stick  end  12
# stick  start  12
# fletching_table  end  4
# fletching_table  start  4
# birch_log  end  2
# birch_log  start  2
# leather  end  6
# leather  start  6
# saddle  end  1
# saddle  start  1
# spruce_log  end  16
# spruce_log  start  16
# smithing_table  end  1
# smithing_table  start  1
# rabbit_hide  end  1
# rabbit_hide  start  1
# iron_ingot  end  1
# iron_ingot  start  1
# cow_spawn_egg  end  2
# cow_spawn_egg  start  2
# lead  end  2
# lead  start  2
# oak_log  end  14
# oak_log  start  19
# spruce_planks  end  8
# spruce_planks  start  8
# 2 [] {'stone_pickaxe': 1}
# 3 [] {'red_glazed_terracotta': 1}
# 21 [] {'blue_glazed_terracotta': 1}
# 36 [] {'glass': 2, 'quartz_block': 2}
# Cosmo (0, 19)
# Alex (5, 19)
# nonuseful_items =  ['gold_ingot', 'smithing_table', 'stick', 'oak_planks', 'fletching_table', 'rabbit_hide', 'glass', 'coal', 'birch_log', 'lead', 'leather', 'red_glazed_terracotta']
# gold_ingot  end  10
# gold_ingot  start  10
# smithing_table  end  3
# smithing_table  start  3
# stick  end  5
# stick  start  5
# oak_planks  end  4
# oak_planks  start  4
# rabbit_hide  end  6
# rabbit_hide  start  6
# glass  end  1
# glass  start  1
# coal  end  13
# coal  start  1
# lead  end  15
# lead  start  15
# leather  end  2
# leather  start  2
# 1 ['coal'] {'coal': 12}
# hoarding_list:  ['coal']
# num_trades =  1
# 3 [] {'cod': 1}
# 19 [] {'oak_boat': 1}
# 26 [] {'pufferfish': 9}
# 30 [] {'tropical_fish': 2}
# GeminiBase18
# Steve (2, 19)
# nonuseful_items =  ['stick', 'oak_planks', 'cod', 'birch_log', 'leather', 'saddle', 'spruce_log', 'string', 'blue_dye', 'rabbit_hide', 'cow_spawn_egg', 'white_wool', 'shears', 'salmon']
# stick  end  2
# stick  start  2
# oak_planks  end  5
# oak_planks  start  5
# cod  end  1
# cod  start  1
# birch_log  end  1
# birch_log  start  1
# leather  end  1
# leather  start  1
# spruce_log  end  19
# spruce_log  start  19
# string  end  1
# string  start  1
# blue_dye  end  10
# blue_dye  start  10
# rabbit_hide  end  1
# rabbit_hide  start  1
# cow_spawn_egg  end  7
# cow_spawn_egg  start  7
# white_wool  end  16
# white_wool  start  16
# shears  end  1
# shears  start  1
# salmon  end  1
# salmon  start  1
# 1 [] {'cooked_porkchop': 5}
# 13 [] {'cooked_beef': 2, 'porkchop': 3}
# Sokka (6, 19)
# nonuseful_items =  ['string', 'blue_dye', 'tropical_fish', 'loom', 'sheep_spawn_egg', 'oak_boat', 'cod', 'diamond_axe', 'turtle_egg', 'oak_log', 'white_wool', 'cooked_porkchop', 'spruce_log', 'chicken']
# blue_dye  end  2
# blue_dye  start  2
# tropical_fish  end  14
# tropical_fish  start  14
# loom  end  3
# loom  start  3
# sheep_spawn_egg  end  4
# sheep_spawn_egg  start  4
# oak_boat  end  1
# oak_boat  start  1
# turtle_egg  end  2
# turtle_egg  start  2
# oak_log  end  19
# oak_log  start  19
# white_wool  end  4
# white_wool  start  4
# spruce_log  end  1
# spruce_log  start  1
# chicken  end  15
# chicken  start  15
# 0 [] {'saddle': 1}
# 1 [] {'saddle': 2}
# 4 [] {'rabbit_hide': 8}
# 20 [] {'leather': 1}
# 22 [] {'leather': 11}
# 23 [] {'leather': 7}
# Negan (5, 19)
# nonuseful_items =  ['stick', 'oak_planks', 'loom', 'diamond_axe', 'birch_log', 'leather', 'beef', 'string', 'cooked_beef', 'porkchop', 'rabbit_stew', 'sheep_spawn_egg', 'cow_spawn_egg', 'lead', 'oak_log', 'shears', 'spruce_planks']
# stick  end  9
# stick  start  9
# oak_planks  end  8
# oak_planks  start  5
# loom  end  5
# loom  start  7
# diamond_axe  end  1
# diamond_axe  start  1
# birch_log  end  15
# birch_log  start  15
# leather  end  7
# leather  start  8
# beef  end  1
# beef  start  1
# string  end  13
# string  start  12
# rabbit_stew  end  1
# rabbit_stew  start  1
# sheep_spawn_egg  end  4
# sheep_spawn_egg  start  5
# cow_spawn_egg  end  2
# cow_spawn_egg  start  2
# lead  end  6
# lead  start  6
# oak_log  end  1
# oak_log  start  1
# spruce_planks  end  3
# spruce_planks  start  3
# 3 [] {'cod': 1, 'salmon': 16, 'tropical_fish': 1}
# 13 ['string', 'oak_planks'] {'string': 1, 'oak_planks': 3}
# hoarding_list:  ['string', 'oak_planks']
# num_trades =  1
# 16 [] {'turtle_egg': 4}
# 20 [] {'cod': 1}
# 23 [] {'tropical_fish': 7}
# Cosmo (4, 19)
# nonuseful_items =  ['blue_dye', 'porkchop', 'rabbit_hide', 'sheep_spawn_egg', 'loom', 'cod', 'turtle_egg', 'cow_spawn_egg', 'leather', 'saddle', 'beef', 'pufferfish']
# blue_dye  end  8
# blue_dye  start  8
# porkchop  end  11
# porkchop  start  11
# rabbit_hide  end  1
# rabbit_hide  start  1
# sheep_spawn_egg  end  1
# sheep_spawn_egg  start  1
# loom  end  1
# cod  end  13
# cod  start  13
# cow_spawn_egg  end  1
# beef  end  18
# beef  start  18
# pufferfish  end  1
# pufferfish  start  1
# 0 [] {'diamond_axe': 1}
# 16 ['loom'] {'loom': 1}
# hoarding_list:  ['loom']
# num_trades =  1
# 22 ['cow_spawn_egg'] {'cow_spawn_egg': 1}
# hoarding_list:  ['cow_spawn_egg']
# num_trades =  2
# 24 [] {'spruce_planks': 1}
# Alex (3, 19)
# nonuseful_items =  ['cooked_beef', 'stick', 'porkchop', 'rabbit_hide', 'tropical_fish', 'oak_boat', 'cod', 'birch_log', 'turtle_egg', 'lead', 'cooked_porkchop', 'spruce_planks', 'chicken', 'salmon', 'pufferfish']
# cooked_beef  end  8
# cooked_beef  start  8
# stick  end  3
# stick  start  3
# porkchop  end  5
# porkchop  start  5
# oak_boat  end  1
# oak_boat  start  1
# birch_log  end  2
# birch_log  start  2
# turtle_egg  end  4
# turtle_egg  start  4
# lead  end  11
# lead  start  11
# cooked_porkchop  end  1
# cooked_porkchop  start  1
# spruce_planks  end  1
# spruce_planks  start  1
# chicken  end  3
# chicken  start  3
# pufferfish  end  8
# pufferfish  start  8
# 3 [] {'shears': 2, 'loom': 1, 'sheep_spawn_egg': 1}
# 4 [] {'string': 1}
# 24 [] {'sheep_spawn_egg': 1}
# GeminiBase2
# Steve (4, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'oak_planks', 'fletching_table', 'porkchop', 'quartz_block', 'coal', 'rabbit_stew', 'iron_ingot', 'diamond_axe', 'birch_log', 'cooked_porkchop', 'stone_pickaxe', 'spruce_planks']
# gold_ingot  end  1
# gold_ingot  start  1
# diamond_sword  end  1
# diamond_sword  start  1
# fletching_table  end  1
# fletching_table  start  1
# porkchop  end  2
# porkchop  start  2
# quartz_block  end  5
# quartz_block  start  5
# coal  end  12
# coal  start  11
# rabbit_stew  end  1
# rabbit_stew  start  1
# iron_ingot  end  19
# iron_ingot  start  19
# birch_log  end  8
# birch_log  start  8
# cooked_porkchop  end  6
# cooked_porkchop  start  6
# spruce_planks  end  1
# spruce_planks  start  1
# 5 [] {'lead': 17}
# 7 ['coal'] {'coal': 1}
# hoarding_list:  ['coal']
# num_trades =  1
# 19 [] {'saddle': 1}
# 21 [] {'cow_spawn_egg': 7}
# Sokka (7, 19)
# nonuseful_items =  ['gold_ingot', 'cooked_beef', 'stick', 'quartz_block', 'glass', 'blue_glazed_terracotta', 'iron_ingot', 'lead', 'cooked_porkchop', 'stone', 'saddle', 'red_glazed_terracotta', 'beef', 'chicken']
# gold_ingot  end  18
# gold_ingot  start  9
# cooked_beef  end  6
# cooked_beef  start  8
# stick  end  2
# stick  start  2
# quartz_block  end  3
# quartz_block  start  3
# glass  end  4
# glass  start  19
# blue_glazed_terracotta  end  9
# blue_glazed_terracotta  start  9
# cooked_porkchop  end  3
# cooked_porkchop  start  3
# stone  end  13
# stone  start  13
# saddle  end  1
# saddle  start  1
# beef  end  2
# beef  start  2
# chicken  end  10
# chicken  start  10
# 3 [] {'birch_log': 2}
# 4 [] {'birch_log': 2}
# 5 [] {'diamond_axe': 1}
# 9 ['gold_ingot'] {'gold_ingot': 9}
# hoarding_list:  ['gold_ingot']
# num_trades =  1
# 16 [] {'diamond_axe': 1}
# 17 [] {'diamond_axe': 1}
# 19 [] {'oak_planks': 7}
# Negan (1, 19)
# nonuseful_items =  ['smithing_table', 'oak_planks', 'rabbit_hide', 'quartz_block', 'coal', 'blue_glazed_terracotta', 'birch_log', 'lead', 'leather', 'stone_pickaxe', 'spruce_log']
# smithing_table  end  4
# smithing_table  start  4
# oak_planks  end  3
# oak_planks  start  3
# rabbit_hide  end  1
# rabbit_hide  start  1
# quartz_block  end  1
# quartz_block  start  1
# coal  end  5
# coal  start  5
# blue_glazed_terracotta  end  1
# blue_glazed_terracotta  start  1
# birch_log  end  2
# birch_log  start  2
# lead  end  1
# lead  start  1
# leather  end  4
# leather  start  4
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# spruce_log  end  9
# spruce_log  start  9
# 4 [] {'cooked_beef': 2}
# Cosmo (4, 19)
# nonuseful_items =  ['cooked_beef', 'stick', 'porkchop', 'rabbit_hide', 'glass', 'rabbit_stew', 'birch_log', 'cow_spawn_egg', 'leather', 'stone_pickaxe', 'spruce_planks', 'red_glazed_terracotta', 'spruce_log', 'beef']
# cooked_beef  end  2
# cooked_beef  start  2
# stick  end  18
# stick  start  18
# porkchop  end  15
# porkchop  start  15
# rabbit_hide  end  1
# rabbit_hide  start  1
# glass  end  1
# glass  start  1
# rabbit_stew  end  1
# rabbit_stew  start  1
# birch_log  end  7
# birch_log  start  9
# cow_spawn_egg  end  7
# cow_spawn_egg  start  7
# leather  end  5
# leather  start  5
# spruce_planks  end  2
# spruce_planks  start  2
# red_glazed_terracotta  end  6
# red_glazed_terracotta  start  9
# spruce_log  end  3
# spruce_log  start  3
# beef  end  2
# beef  start  2
# 3 [] {'iron_ingot': 1}
# 6 [] {'coal': 2}
# 15 [] {'diamond_sword': 1}
# 21 ['lead'] {'lead': 7}
# Alex (6, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'fletching_table', 'diamond_axe', 'birch_log', 'leather', 'saddle', 'beef', 'chicken', 'smithing_table', 'porkchop', 'rabbit_hide', 'coal', 'cow_spawn_egg', 'oak_log']
# gold_ingot  end  1
# gold_ingot  start  10
# diamond_sword  end  1
# diamond_sword  start  1
# fletching_table  end  7
# fletching_table  start  7
# diamond_axe  end  1
# diamond_axe  start  1
# birch_log  end  1
# birch_log  start  1
# leather  end  3
# leather  start  3
# saddle  end  2
# saddle  start  2
# beef  end  2
# beef  start  2
# chicken  end  5
# chicken  start  5
# smithing_table  end  5
# smithing_table  start  5
# porkchop  end  3
# porkchop  start  3
# rabbit_hide  end  2
# rabbit_hide  start  2
# cow_spawn_egg  end  3
# cow_spawn_egg  start  3
# oak_log  end  16
# oak_log  start  16
# 6 [] {'stone_pickaxe': 1}
# 7 [] {'stone_pickaxe': 1}
# 9 [] {'glass': 4}
# 15 [] {'red_glazed_terracotta': 3}
# 16 [] {'red_glazed_terracotta': 1}
# 17 [] {'glass': 11}
# GeminiBase3
# Steve (1, 19)
# nonuseful_items =  ['oak_planks', 'porkchop', 'carrot', 'birch_log', 'cow_spawn_egg', 'oak_log', 'potato', 'saddle', 'spruce_planks', 'spruce_log', 'beef', 'chicken']
# oak_planks  end  7
# oak_planks  start  7
# porkchop  end  3
# porkchop  start  3
# carrot  end  11
# carrot  start  11
# birch_log  end  1
# birch_log  start  1
# cow_spawn_egg  end  1
# cow_spawn_egg  start  1
# oak_log  end  2
# oak_log  start  2
# potato  end  13
# potato  start  13
# saddle  end  1
# saddle  start  1
# spruce_planks  end  8
# spruce_planks  start  8
# spruce_log  end  8
# spruce_log  start  8
# beef  end  1
# beef  start  1
# chicken  end  2
# chicken  start  2
# 21 [] {'diamond_sword': 1}
# Sokka (3, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'wheat', 'smithing_table', 'bread', 'fletching_table', 'porkchop', 'coal', 'cooked_porkchop', 'spruce_log']
# gold_ingot  end  2
# gold_ingot  start  2
# diamond_sword  end  1
# diamond_sword  start  1
# wheat  end  12
# wheat  start  12
# smithing_table  end  2
# smithing_table  start  2
# bread  end  1
# bread  start  1
# fletching_table  end  1
# fletching_table  start  1
# porkchop  end  10
# porkchop  start  15
# coal  end  18
# coal  start  18
# cooked_porkchop  end  7
# cooked_porkchop  start  7
# spruce_log  end  1
# spruce_log  start  1
# 2 [] {'cow_spawn_egg': 1}
# 5 [] {'rabbit_hide': 1}
# 21 [] {'saddle': 1}
# Negan (6, 19)
# nonuseful_items =  ['wheat', 'smithing_table', 'stick', 'oak_planks', 'bread', 'fletching_table', 'rabbit_hide', 'coal', 'diamond_axe', 'birch_log', 'lead', 'oak_log', 'pumpkin', 'mushroom_stew']
# wheat  end  1
# wheat  start  1
# smithing_table  end  1
# smithing_table  start  1
# stick  end  12
# stick  start  12
# oak_planks  end  1
# oak_planks  start  1
# fletching_table  end  5
# fletching_table  start  5
# coal  end  1
# coal  start  1
# diamond_axe  end  1
# diamond_axe  start  1
# birch_log  end  19
# birch_log  start  19
# lead  end  1
# lead  start  1
# oak_log  end  3
# oak_log  start  3
# pumpkin  end  1
# pumpkin  start  1
# mushroom_stew  end  1
# mushroom_stew  start  1
# 0 [] {'beef': 8, 'chicken': 6}
# 1 [] {'beef': 1}
# 5 [] {'porkchop': 5}
# 6 [] {'beef': 4}
# 8 [] {'cooked_beef': 5}
# 20 [] {'cooked_beef': 5}
# Cosmo (6, 19)
# nonuseful_items =  ['gold_ingot', 'stick', 'carrot', 'leather', 'beef', 'pumpkin', 'chicken', 'cooked_beef', 'porkchop', 'rabbit_hide', 'coal', 'rabbit_stew', 'cow_spawn_egg', 'potato', 'cooked_porkchop', 'mushroom_stew']
# gold_ingot  end  15
# gold_ingot  start  13
# stick  end  1
# stick  start  1
# carrot  end  2
# carrot  start  2
# leather  end  13
# leather  start  12
# beef  end  4
# beef  start  16
# chicken  end  12
# chicken  start  18
# cooked_beef  end  5
# porkchop  end  7
# porkchop  start  1
# rabbit_hide  end  6
# rabbit_hide  start  6
# coal  end  1
# coal  start  1
# rabbit_stew  end  1
# rabbit_stew  start  1
# cow_spawn_egg  end  5
# cow_spawn_egg  start  6
# potato  end  2
# potato  start  2
# cooked_porkchop  end  3
# cooked_porkchop  start  1
# mushroom_stew  end  1
# mushroom_stew  start  1
# 0 ['cooked_beef', 'cooked_porkchop'] {'cooked_beef': 5, 'cooked_porkchop': 2}
# hoarding_list:  ['cooked_beef', 'cooked_porkchop']
# num_trades =  1
# 2 ['leather'] {'leather': 1}
# hoarding_list:  ['leather']
# num_trades =  2
# 4 ['gold_ingot'] {'gold_ingot': 2}
# hoarding_list:  ['gold_ingot']
# num_trades =  3
# 6 ['cooked_beef'] {'cooked_beef': 5}
# hoarding_list:  ['cooked_beef']
# num_trades =  4
# 8 ['porkchop'] {'porkchop': 6}
# hoarding_list:  ['porkchop']
# num_trades =  5
# 20 [] {'oak_planks': 1}
# Alex (2, 19)
# nonuseful_items =  ['gold_ingot', 'fletching_table', 'diamond_axe', 'leather', 'spruce_log', 'beef', 'smithing_table', 'rabbit_hide', 'rabbit_stew', 'iron_ingot', 'cow_spawn_egg', 'lead', 'oak_log', 'spruce_planks']
# gold_ingot  end  5
# gold_ingot  start  5
# fletching_table  end  2
# fletching_table  start  2
# diamond_axe  end  1
# diamond_axe  start  1
# leather  end  7
# leather  start  7
# spruce_log  end  10
# spruce_log  start  10
# smithing_table  end  1
# smithing_table  start  1
# rabbit_hide  end  3
# rabbit_hide  start  3
# rabbit_stew  end  1
# rabbit_stew  start  1
# iron_ingot  end  20
# iron_ingot  start  20
# cow_spawn_egg  end  3
# cow_spawn_egg  start  3
# lead  end  15
# lead  start  15
# oak_log  end  2
# oak_log  start  2
# spruce_planks  end  1
# spruce_planks  start  1
# 1 [] {'bread': 9}
# 4 [] {'pumpkin': 2}
# GeminiBase4
# Steve (3, 19)
# nonuseful_items =  ['wheat', 'carrot', 'pumpkin', 'beef', 'chicken', 'string', 'cooked_beef', 'blue_dye', 'porkchop', 'glass', 'blue_glazed_terracotta', 'white_wool', 'cooked_porkchop', 'red_glazed_terracotta', 'mushroom_stew']
# wheat  end  6
# wheat  start  6
# carrot  end  1
# carrot  start  1
# pumpkin  end  1
# pumpkin  start  1
# beef  end  17
# beef  start  17
# chicken  end  5
# chicken  start  5
# string  end  10
# string  start  1
# blue_dye  end  9
# blue_dye  start  19
# porkchop  end  18
# porkchop  start  18
# glass  end  9
# glass  start  9
# blue_glazed_terracotta  end  2
# blue_glazed_terracotta  start  2
# white_wool  end  5
# white_wool  start  15
# red_glazed_terracotta  end  9
# red_glazed_terracotta  start  9
# mushroom_stew  end  1
# mushroom_stew  start  1
# 0 [] {'iron_ingot': 5, 'gold_ingot': 5, 'smithing_table': 1}
# 2 ['string'] {'coal': 10, 'string': 10}
# hoarding_list:  ['string']
# 10 [] {'iron_ingot': 2, 'gold_ingot': 2}
# Sokka (2, 19)
# nonuseful_items =  ['diamond_sword', 'loom', 'chicken', 'string', 'cooked_beef', 'blue_dye', 'porkchop', 'glass', 'blue_glazed_terracotta', 'rabbit_stew', 'iron_ingot', 'white_wool', 'cooked_porkchop', 'shears', 'stone']
# diamond_sword  end  1
# diamond_sword  start  1
# loom  end  1
# loom  start  1
# chicken  end  11
# chicken  start  11
# string  end  1
# string  start  2
# cooked_beef  end  9
# cooked_beef  start  9
# blue_dye  end  1
# blue_dye  start  1
# porkchop  end  1
# porkchop  start  1
# glass  end  10
# glass  start  10
# blue_glazed_terracotta  end  3
# blue_glazed_terracotta  start  3
# rabbit_stew  end  1
# rabbit_stew  start  1
# iron_ingot  end  8
# iron_ingot  start  8
# white_wool  end  1
# white_wool  start  1
# cooked_porkchop  end  1
# cooked_porkchop  start  1
# shears  end  1
# shears  start  1
# stone  end  11
# stone  start  11
# 1 [] {'wheat': 1}
# 9 [] {'wheat': 1}
# Negan (3, 19)
# nonuseful_items =  ['gold_ingot', 'wheat', 'bread', 'fletching_table', 'quartz_block', 'loom', 'stone_pickaxe', 'pumpkin', 'smithing_table', 'string', 'coal', 'iron_ingot', 'sheep_spawn_egg', 'potato', 'white_wool', 'shears', 'stone']
# gold_ingot  end  1
# gold_ingot  start  1
# bread  end  2
# bread  start  2
# fletching_table  end  1
# fletching_table  start  1
# quartz_block  end  15
# quartz_block  start  15
# loom  end  1
# loom  start  1
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# pumpkin  end  6
# pumpkin  start  6
# smithing_table  end  2
# smithing_table  start  2
# string  end  7
# string  start  17
# coal  end  9
# coal  start  19
# iron_ingot  end  1
# iron_ingot  start  1
# sheep_spawn_egg  end  8
# sheep_spawn_egg  start  8
# potato  end  5
# potato  start  5
# white_wool  end  4
# white_wool  start  4
# shears  end  1
# shears  start  1
# stone  end  1
# stone  start  1
# 2 [] {'cooked_beef': 1, 'cooked_porkchop': 6}
# 9 [] {'cooked_beef': 9}
# 11 [] {'rabbit_stew': 1}
# Cosmo (2, 19)
# nonuseful_items =  ['wheat', 'fletching_table', 'sheep_spawn_egg', 'loom', 'shears', 'beef', 'mushroom_stew']
# wheat  end  4
# wheat  start  4
# fletching_table  end  9
# fletching_table  start  9
# sheep_spawn_egg  end  1
# sheep_spawn_egg  start  1
# loom  end  6
# beef  end  1
# beef  start  1
# mushroom_stew  end  1
# mushroom_stew  start  1
# 12 ['loom'] {'loom': 6}
# hoarding_list:  ['loom']
# num_trades =  1
# 14 [] {'red_glazed_terracotta': 1, 'blue_glazed_terracotta': 1}
# Alex (6, 19)
# nonuseful_items =  ['gold_ingot', 'wheat', 'smithing_table', 'bread', 'porkchop', 'coal', 'blue_glazed_terracotta', 'rabbit_stew', 'iron_ingot', 'stone_pickaxe', 'potato', 'red_glazed_terracotta', 'chicken', 'mushroom_stew']
# gold_ingot  end  5
# gold_ingot  start  12
# wheat  end  2
# wheat  start  3
# bread  end  7
# bread  start  7
# porkchop  end  1
# porkchop  start  1
# coal  end  1
# coal  start  1
# blue_glazed_terracotta  end  5
# blue_glazed_terracotta  start  5
# iron_ingot  end  4
# iron_ingot  start  11
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# potato  end  1
# potato  start  1
# red_glazed_terracotta  end  1
# red_glazed_terracotta  start  1
# chicken  end  4
# chicken  start  4
# mushroom_stew  end  1
# mushroom_stew  start  1
# 0 [] {'string': 1, 'white_wool': 10, 'blue_dye': 10}
# 1 [] {'string': 1}
# 10 [] {'string': 10, 'white_wool': 5}
# 11 [] {'string': 2}
# 12 [] {'shears': 1}
# 14 [] {'loom': 1}
# GeminiBase5
# Steve (4, 19)
# nonuseful_items =  ['string', 'stick', 'blue_dye', 'quartz_block', 'glass', 'blue_glazed_terracotta', 'loom', 'sheep_spawn_egg', 'oak_boat', 'turtle_egg', 'lead', 'leather']
# string  end  4
# string  start  4
# stick  end  19
# stick  start  19
# blue_dye  end  13
# blue_dye  start  13
# quartz_block  end  2
# quartz_block  start  2
# glass  end  6
# glass  start  6
# blue_glazed_terracotta  end  2
# blue_glazed_terracotta  start  3
# loom  end  7
# loom  start  7
# sheep_spawn_egg  end  1
# sheep_spawn_egg  start  1
# oak_boat  end  1
# oak_boat  start  1
# turtle_egg  end  1
# turtle_egg  start  1
# lead  end  2
# lead  start  2
# 4 [] {'cooked_beef': 2}
# 10 [] {'chicken': 1}
# 12 [] {'porkchop': 1}
# 23 [] {'beef': 2, 'chicken': 15}
# Sokka (7, 19)
# nonuseful_items =  ['cooked_beef', 'rabbit_hide', 'tropical_fish', 'rabbit_stew', 'sheep_spawn_egg', 'cod', 'turtle_egg', 'cow_spawn_egg', 'white_wool', 'shears', 'saddle', 'beef', 'chicken', 'pufferfish']
# cooked_beef  end  2
# cooked_beef  start  4
# rabbit_hide  end  1
# rabbit_hide  start  1
# tropical_fish  end  13
# tropical_fish  start  13
# cod  end  16
# cod  start  16
# cow_spawn_egg  end  2
# cow_spawn_egg  start  2
# white_wool  end  6
# white_wool  start  6
# shears  end  1
# shears  start  1
# saddle  end  1
# saddle  start  1
# beef  end  2
# beef  start  2
# chicken  end  15
# chicken  start  15
# pufferfish  end  4
# pufferfish  start  6
# 0 [] {'quartz_block': 1}
# 3 [] {'quartz_block': 1}
# 4 [] {'blue_glazed_terracotta': 1}
# 5 [] {'red_glazed_terracotta': 1}
# 15 [] {'red_glazed_terracotta': 2}
# 16 [] {'red_glazed_terracotta': 2}
# 23 [] {'blue_glazed_terracotta': 1}
# Negan (5, 19)
# nonuseful_items =  ['cooked_beef', 'porkchop', 'quartz_block', 'glass', 'blue_glazed_terracotta', 'rabbit_stew', 'cow_spawn_egg', 'lead', 'leather', 'white_wool', 'cooked_porkchop', 'red_glazed_terracotta', 'beef']
# cooked_beef  end  2
# cooked_beef  start  2
# porkchop  end  19
# porkchop  start  19
# quartz_block  end  2
# quartz_block  start  4
# glass  end  9
# glass  start  9
# blue_glazed_terracotta  end  6
# blue_glazed_terracotta  start  6
# rabbit_stew  end  1
# rabbit_stew  start  1
# cow_spawn_egg  end  1
# cow_spawn_egg  start  1
# white_wool  end  2
# white_wool  start  2
# cooked_porkchop  end  1
# cooked_porkchop  start  1
# beef  end  10
# beef  start  10
# 0 [] {'pufferfish': 2}
# 2 [] {'tropical_fish': 6, 'pufferfish': 3}
# 3 [] {'turtle_egg': 1}
# 5 ['rabbit_stew'] {'rabbit_stew': 1}
# 6 [] {'turtle_egg': 5}
# Cosmo (10, 19)
# nonuseful_items =  ['string', 'porkchop', 'glass', 'tropical_fish', 'rabbit_stew', 'loom', 'sheep_spawn_egg', 'turtle_egg', 'cooked_porkchop', 'stone_pickaxe', 'shears', 'chicken', 'pufferfish']
# string  end  16
# string  start  16
# glass  end  1
# glass  start  1
# rabbit_stew  end  1
# rabbit_stew  start  1
# loom  end  2
# loom  start  2
# sheep_spawn_egg  end  1
# sheep_spawn_egg  start  7
# turtle_egg  end  3
# turtle_egg  start  3
# cooked_porkchop  end  5
# cooked_porkchop  start  5
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# shears  end  1
# shears  start  1
# 2 [] {'leather': 1, 'lead': 1}
# 10 [] {'leather': 1}
# 12 [] {'leather': 2}
# 17 [] {'lead': 1}
# 18 [] {'lead': 1}
# 20 [] {'lead': 1}
# 21 [] {'lead': 1}
# 22 [] {'lead': 1}
# 24 [] {'lead': 1}
# 25 [] {'lead': 1}
# Alex (10, 19)
# nonuseful_items =  ['stick', 'tropical_fish', 'oak_boat', 'cod', 'turtle_egg', 'leather', 'stone_pickaxe', 'saddle', 'beef', 'chicken', 'pufferfish', 'cooked_beef', 'glass', 'cow_spawn_egg', 'lead', 'cooked_porkchop', 'stone', 'red_glazed_terracotta']
# stick  end  1
# stick  start  1
# tropical_fish  end  1
# tropical_fish  start  1
# oak_boat  end  1
# oak_boat  start  1
# cod  end  3
# cod  start  3
# leather  end  7
# leather  start  7
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# saddle  end  1
# saddle  start  1
# beef  end  7
# beef  start  7
# chicken  end  4
# chicken  start  4
# pufferfish  end  1
# pufferfish  start  1
# cooked_beef  end  1
# cooked_beef  start  1
# glass  end  4
# glass  start  4
# cow_spawn_egg  end  8
# cow_spawn_egg  start  7
# lead  end  8
# lead  start  14
# cooked_porkchop  end  4
# cooked_porkchop  start  4
# stone  end  19
# stone  start  19
# red_glazed_terracotta  end  5
# red_glazed_terracotta  start  9
# 6 ['cow_spawn_egg'] {'cow_spawn_egg': 1}
# hoarding_list:  ['cow_spawn_egg']
# num_trades =  1
# 15 [] {'sheep_spawn_egg': 1}
# 16 [] {'sheep_spawn_egg': 1}
# 17 [] {'sheep_spawn_egg': 1}
# 18 [] {'sheep_spawn_egg': 1}
# 20 [] {'sheep_spawn_egg': 1}
# 21 [] {'sheep_spawn_egg': 1}
# 22 [] {'sheep_spawn_egg': 1}
# 24 [] {'sheep_spawn_egg': 1}
# 25 [] {'sheep_spawn_egg': 1}
# GeminiBase8
# Steve (5, 19)
# nonuseful_items =  ['wheat', 'bread', 'tropical_fish', 'loom', 'oak_boat', 'stone_pickaxe', 'pufferfish', 'string', 'blue_dye', 'sheep_spawn_egg', 'white_wool', 'potato', 'shears', 'stone', 'red_glazed_terracotta', 'mushroom_stew']
# bread  end  1
# bread  start  1
# tropical_fish  end  1
# tropical_fish  start  2
# loom  end  5
# loom  start  5
# oak_boat  end  1
# oak_boat  start  1
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# pufferfish  end  6
# pufferfish  start  6
# string  end  2
# string  start  2
# blue_dye  end  9
# blue_dye  start  9
# sheep_spawn_egg  end  2
# sheep_spawn_egg  start  2
# white_wool  end  5
# white_wool  start  5
# shears  end  1
# shears  start  1
# stone  end  3
# stone  start  3
# red_glazed_terracotta  end  6
# red_glazed_terracotta  start  7
# mushroom_stew  end  1
# mushroom_stew  start  1
# 3 [] {'beef': 7}
# 8 [] {'porkchop': 2}
# 12 [] {'chicken': 1, 'rabbit_stew': 1}
# 19 [] {'cooked_beef': 1}
# 22 [] {'rabbit_stew': 1}
# Sokka (5, 19)
# nonuseful_items =  ['string', 'blue_dye', 'porkchop', 'glass', 'blue_glazed_terracotta', 'tropical_fish', 'loom', 'white_wool', 'beef', 'salmon']
# blue_dye  end  1
# blue_dye  start  1
# porkchop  end  9
# porkchop  start  11
# glass  end  14
# glass  start  14
# tropical_fish  end  10
# tropical_fish  start  10
# loom  end  4
# loom  start  4
# white_wool  end  11
# white_wool  start  14
# salmon  end  2
# salmon  start  2
# 0 [] {'bread': 2}
# 3 [] {'potato': 14}
# 6 [] {'pumpkin': 3}
# 8 [] {'wheat': 2}
# 21 [] {'carrot': 1}
# Negan (2, 19)
# nonuseful_items =  ['wheat', 'quartz_block', 'tropical_fish', 'carrot', 'oak_boat', 'cod', 'chicken', 'pufferfish', 'cooked_beef', 'porkchop', 'glass', 'blue_glazed_terracotta', 'rabbit_stew', 'potato', 'red_glazed_terracotta']
# wheat  end  16
# wheat  start  15
# quartz_block  end  10
# quartz_block  start  10
# tropical_fish  end  8
# tropical_fish  start  8
# carrot  end  2
# carrot  start  2
# oak_boat  end  1
# oak_boat  start  1
# cod  end  18
# cod  start  19
# chicken  end  15
# chicken  start  15
# pufferfish  end  1
# pufferfish  start  2
# cooked_beef  end  1
# cooked_beef  start  1
# porkchop  end  1
# glass  end  2
# glass  start  2
# blue_glazed_terracotta  end  3
# blue_glazed_terracotta  start  3
# rabbit_stew  end  1
# rabbit_stew  start  1
# potato  end  1
# red_glazed_terracotta  end  3
# red_glazed_terracotta  start  3
# 15 ['potato', 'wheat', 'porkchop'] {'potato': 1, 'wheat': 1, 'porkchop': 1}
# hoarding_list:  ['potato', 'wheat', 'porkchop']
# num_trades =  1
# 23 ['stone_pickaxe'] {'stone_pickaxe': 1}
# Cosmo (4, 19)
# nonuseful_items =  ['wheat', 'bread', 'quartz_block', 'carrot', 'pumpkin', 'beef', 'cooked_beef', 'blue_dye', 'porkchop', 'rabbit_stew', 'sheep_spawn_egg', 'white_wool', 'potato', 'shears', 'stone']
# bread  end  1
# bread  start  1
# quartz_block  end  9
# quartz_block  start  9
# carrot  end  1
# carrot  start  1
# pumpkin  end  1
# pumpkin  start  1
# beef  end  13
# beef  start  13
# cooked_beef  end  1
# cooked_beef  start  2
# blue_dye  end  10
# blue_dye  start  10
# rabbit_stew  end  1
# rabbit_stew  start  1
# sheep_spawn_egg  end  7
# sheep_spawn_egg  start  7
# white_wool  end  1
# white_wool  start  1
# potato  end  3
# potato  start  4
# shears  end  1
# shears  start  1
# stone  end  1
# stone  start  1
# 15 [] {'oak_boat': 1, 'pufferfish': 1, 'cod': 1}
# 19 [] {'tropical_fish': 1}
# 21 [] {'tropical_fish': 1}
# 22 [] {'tropical_fish': 1}
# Alex (4, 19)
# nonuseful_items =  ['bread', 'loom', 'carrot', 'cod', 'turtle_egg', 'pumpkin', 'chicken', 'pufferfish', 'string', 'cooked_beef', 'rabbit_stew', 'sheep_spawn_egg', 'potato', 'cooked_porkchop', 'white_wool', 'shears', 'mushroom_stew']
# bread  end  6
# bread  start  8
# loom  end  1
# loom  start  1
# carrot  end  15
# carrot  start  12
# cod  end  1
# cod  start  1
# turtle_egg  end  1
# turtle_egg  start  1
# pufferfish  end  2
# pufferfish  start  2
# string  end  8
# string  start  5
# cooked_beef  end  7
# cooked_beef  start  7
# sheep_spawn_egg  end  1
# sheep_spawn_egg  start  1
# potato  end  2
# potato  start  2
# cooked_porkchop  end  9
# cooked_porkchop  start  9
# white_wool  end  3
# shears  end  1
# shears  start  1
# mushroom_stew  end  1
# mushroom_stew  start  1
# 0 [] {'blue_glazed_terracotta': 1}
# 6 ['carrot', 'string', 'white_wool'] {'carrot': 3, 'string': 3, 'white_wool': 3}
# hoarding_list:  ['carrot', 'string', 'white_wool']
# num_trades =  1
# 12 [] {'stone_pickaxe': 1, 'red_glazed_terracotta': 1}
# 23 [] {'quartz_block': 3}
# GeminiComp1
# Steve (4, 19)
# nonuseful_items =  ['gold_ingot', 'fletching_table', 'quartz_block', 'stone_pickaxe', 'saddle', 'beef', 'cooked_beef', 'porkchop', 'rabbit_hide', 'glass', 'coal', 'blue_glazed_terracotta', 'iron_ingot', 'lead', 'cooked_porkchop', 'red_glazed_terracotta']
# gold_ingot  end  2
# gold_ingot  start  2
# fletching_table  end  3
# fletching_table  start  3
# quartz_block  end  1
# quartz_block  start  1
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# saddle  end  1
# saddle  start  1
# beef  end  2
# beef  start  2
# cooked_beef  end  1
# cooked_beef  start  1
# porkchop  end  2
# porkchop  start  2
# rabbit_hide  end  8
# rabbit_hide  start  8
# glass  end  5
# glass  start  6
# coal  end  19
# coal  start  19
# blue_glazed_terracotta  end  8
# blue_glazed_terracotta  start  8
# iron_ingot  end  5
# iron_ingot  start  5
# lead  end  1
# lead  start  1
# cooked_porkchop  end  3
# cooked_porkchop  start  4
# red_glazed_terracotta  end  2
# red_glazed_terracotta  start  2
# 5 [] {'bread': 1, 'carrot': 2}
# 9 [] {'pumpkin': 1}
# 12 ['red_glazed_terracotta'] {'red_glazed_terracotta': 1}
# 13 [] {'wheat': 5}
# Sokka (9, 19)
# nonuseful_items =  ['wheat', 'cooked_beef', 'bread', 'fletching_table', 'rabbit_hide', 'rabbit_stew', 'carrot', 'cow_spawn_egg', 'lead', 'leather', 'pumpkin', 'beef', 'chicken', 'mushroom_stew']
# fletching_table  end  5
# fletching_table  start  5
# rabbit_hide  end  1
# rabbit_hide  start  1
# rabbit_stew  end  1
# rabbit_stew  start  1
# cow_spawn_egg  end  1
# cow_spawn_egg  start  1
# lead  end  1
# lead  start  4
# pumpkin  end  2
# pumpkin  start  3
# mushroom_stew  end  1
# mushroom_stew  start  1
# 1 [] {'quartz_block': 1}
# 3 [] {'stone': 13}
# 5 [] {'glass': 1, 'stone_pickaxe': 1}
# 6 [] {'stone_pickaxe': 1}
# 7 [] {'red_glazed_terracotta': 1}
# 9 [] {'red_glazed_terracotta': 1}
# 10 [] {'red_glazed_terracotta': 1}
# 13 [] {'glass': 1}
# 15 [] {'glass': 3}
# Negan (3, 19)
# nonuseful_items =  ['wheat', 'cooked_beef', 'stick', 'porkchop', 'quartz_block', 'glass', 'carrot', 'cow_spawn_egg', 'lead', 'stone_pickaxe', 'potato', 'cooked_porkchop', 'leather', 'stone', 'red_glazed_terracotta', 'chicken']
# wheat  end  13
# wheat  start  13
# cooked_beef  end  1
# cooked_beef  start  1
# stick  end  2
# stick  start  2
# porkchop  end  9
# porkchop  start  9
# quartz_block  end  14
# quartz_block  start  14
# glass  end  11
# glass  start  11
# carrot  end  3
# carrot  start  3
# cow_spawn_egg  end  1
# cow_spawn_egg  start  1
# lead  end  4
# lead  start  1
# potato  end  9
# potato  start  9
# cooked_porkchop  end  4
# cooked_porkchop  start  4
# leather  end  6
# stone  end  7
# stone  start  7
# red_glazed_terracotta  end  2
# red_glazed_terracotta  start  3
# chicken  end  6
# chicken  start  6
# 6 ['leather'] {'leather': 6}
# hoarding_list:  ['leather']
# num_trades =  1
# 7 ['lead'] {'lead': 3}
# hoarding_list:  ['lead']
# num_trades =  2
# 17 [] {'iron_ingot': 1}
# Cosmo (5, 19)
# nonuseful_items =  ['diamond_sword', 'wheat', 'fletching_table', 'quartz_block', 'leather', 'pumpkin', 'coal', 'blue_glazed_terracotta', 'iron_ingot', 'cow_spawn_egg', 'lead', 'potato', 'red_glazed_terracotta', 'mushroom_stew']
# diamond_sword  end  1
# diamond_sword  start  1
# wheat  end  1
# wheat  start  1
# fletching_table  end  1
# fletching_table  start  1
# leather  end  4
# leather  start  4
# pumpkin  end  1
# pumpkin  start  1
# coal  end  1
# coal  start  1
# blue_glazed_terracotta  end  1
# blue_glazed_terracotta  start  1
# iron_ingot  end  1
# iron_ingot  start  1
# cow_spawn_egg  end  4
# cow_spawn_egg  start  4
# lead  end  13
# lead  start  13
# potato  end  4
# potato  start  4
# red_glazed_terracotta  end  2
# red_glazed_terracotta  start  5
# mushroom_stew  end  1
# mushroom_stew  start  1
# 1 [] {'cooked_beef': 7}
# 10 [] {'beef': 2, 'chicken': 1}
# 11 [] {'cooked_porkchop': 2}
# 12 [] {'cooked_porkchop': 1}
# 17 [] {'cooked_porkchop': 2}
# Alex (3, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'wheat', 'bread', 'fletching_table', 'quartz_block', 'carrot', 'pumpkin', 'beef', 'chicken', 'smithing_table', 'glass', 'rabbit_stew', 'iron_ingot', 'potato', 'cooked_porkchop', 'stone']
# gold_ingot  end  17
# gold_ingot  start  17
# diamond_sword  end  1
# diamond_sword  start  1
# wheat  end  1
# wheat  start  1
# bread  end  8
# bread  start  8
# fletching_table  end  1
# fletching_table  start  1
# quartz_block  end  4
# quartz_block  start  4
# carrot  end  15
# carrot  start  15
# pumpkin  end  6
# pumpkin  start  6
# beef  end  11
# beef  start  11
# chicken  end  4
# smithing_table  end  6
# smithing_table  start  6
# glass  end  3
# glass  start  3
# rabbit_stew  end  1
# rabbit_stew  start  1
# iron_ingot  end  14
# iron_ingot  start  14
# potato  end  1
# potato  start  1
# 3 [] {'leather': 6}
# 11 ['chicken'] {'chicken': 4}
# hoarding_list:  ['chicken']
# num_trades =  1
# 15 [] {'lead': 1}
# GeminiComp2
# Steve (3, 19)
# nonuseful_items =  ['diamond_sword', 'smithing_table', 'stick', 'coal', 'loom', 'sheep_spawn_egg', 'leather', 'white_wool', 'stone_pickaxe', 'stone', 'red_glazed_terracotta']
# diamond_sword  end  1
# diamond_sword  start  1
# smithing_table  end  1
# smithing_table  start  1
# stick  end  1
# stick  start  1
# coal  end  17
# coal  start  17
# loom  end  2
# loom  start  2
# sheep_spawn_egg  end  1
# sheep_spawn_egg  start  1
# leather  end  1
# leather  start  1
# white_wool  end  1
# white_wool  start  1
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# stone  end  5
# stone  start  6
# 0 [] {'rabbit_stew': 1}
# 6 [] {'beef': 4}
# 8 [] {'chicken': 2}
# Sokka (1, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'stick', 'fletching_table', 'quartz_block', 'leather', 'chicken', 'smithing_table', 'rabbit_hide', 'coal', 'blue_glazed_terracotta', 'rabbit_stew', 'iron_ingot', 'cow_spawn_egg', 'lead', 'stone', 'red_glazed_terracotta']
# gold_ingot  end  16
# gold_ingot  start  16
# diamond_sword  end  1
# diamond_sword  start  1
# stick  end  2
# stick  start  2
# fletching_table  end  2
# fletching_table  start  2
# quartz_block  end  5
# quartz_block  start  5
# leather  end  1
# leather  start  1
# chicken  end  13
# chicken  start  13
# smithing_table  end  4
# smithing_table  start  4
# rabbit_hide  end  1
# rabbit_hide  start  1
# coal  end  2
# coal  start  2
# blue_glazed_terracotta  end  3
# blue_glazed_terracotta  start  3
# rabbit_stew  end  1
# rabbit_stew  start  1
# iron_ingot  end  10
# iron_ingot  start  10
# cow_spawn_egg  end  9
# cow_spawn_egg  start  9
# lead  end  7
# lead  start  7
# stone  end  12
# stone  start  12
# red_glazed_terracotta  end  1
# red_glazed_terracotta  start  1
# 8 ['coal'] {'coal': 2}
# Negan (2, 19)
# nonuseful_items =  ['gold_ingot', 'stick', 'loom', 'leather', 'saddle', 'beef', 'chicken', 'smithing_table', 'porkchop', 'rabbit_hide', 'rabbit_stew', 'iron_ingot', 'sheep_spawn_egg', 'cow_spawn_egg', 'lead', 'shears']
# gold_ingot  end  1
# gold_ingot  start  1
# stick  end  17
# stick  start  17
# loom  end  1
# loom  start  1
# leather  end  10
# leather  start  10
# saddle  end  1
# saddle  start  1
# beef  end  8
# beef  start  8
# chicken  end  5
# chicken  start  5
# smithing_table  end  2
# smithing_table  start  2
# porkchop  end  4
# porkchop  start  4
# rabbit_hide  end  4
# rabbit_hide  start  4
# iron_ingot  end  1
# iron_ingot  start  1
# sheep_spawn_egg  end  2
# sheep_spawn_egg  start  2
# cow_spawn_egg  end  1
# cow_spawn_egg  start  1
# lead  end  1
# lead  start  1
# shears  end  1
# shears  start  1
# 0 [] {'red_glazed_terracotta': 1}
# 6 [] {'stone': 1}
# Cosmo (0, 19)
# Alex (0, 19)
# GeminiComp3
# Steve (6, 19)
# nonuseful_items =  ['diamond_sword', 'smithing_table', 'blue_dye', 'oak_planks', 'coal', 'tropical_fish', 'sheep_spawn_egg', 'birch_log', 'white_wool', 'shears', 'spruce_log', 'pufferfish']
# diamond_sword  end  1
# diamond_sword  start  1
# smithing_table  end  8
# smithing_table  start  8
# blue_dye  end  1
# blue_dye  start  1
# oak_planks  end  1
# oak_planks  start  1
# coal  end  4
# coal  start  10
# tropical_fish  end  11
# tropical_fish  start  12
# sheep_spawn_egg  end  2
# sheep_spawn_egg  start  3
# birch_log  end  1
# birch_log  start  1
# white_wool  end  4
# white_wool  start  4
# shears  end  1
# shears  start  1
# spruce_log  end  1
# spruce_log  start  1
# 0 [] {'saddle': 1}
# 4 [] {'leather': 1, 'rabbit_hide': 1}
# 7 [] {'lead': 1}
# 9 [] {'leather': 1}
# 11 [] {'lead': 1}
# 14 [] {'lead': 1}
# Sokka (6, 19)
# nonuseful_items =  ['oak_planks', 'tropical_fish', 'oak_boat', 'cod', 'diamond_axe', 'birch_log', 'turtle_egg', 'leather', 'saddle', 'spruce_log', 'rabbit_hide', 'coal', 'cow_spawn_egg', 'lead', 'oak_log', 'salmon']
# oak_planks  end  9
# oak_planks  start  9
# tropical_fish  end  1
# tropical_fish  start  1
# cod  end  1
# cod  start  1
# diamond_axe  end  1
# diamond_axe  start  1
# birch_log  end  5
# birch_log  start  5
# turtle_egg  end  7
# turtle_egg  start  8
# leather  end  8
# leather  start  8
# saddle  end  1
# saddle  start  2
# spruce_log  end  9
# spruce_log  start  9
# rabbit_hide  end  8
# rabbit_hide  start  8
# coal  end  1
# coal  start  1
# cow_spawn_egg  end  4
# cow_spawn_egg  start  2
# lead  end  2
# lead  start  2
# oak_log  end  5
# oak_log  start  5
# salmon  end  8
# salmon  start  8
# 0 ['cow_spawn_egg'] {'cow_spawn_egg': 2}
# hoarding_list:  ['cow_spawn_egg']
# num_trades =  1
# 2 [] {'sheep_spawn_egg': 1}
# 3 [] {'string': 19, 'blue_dye': 5}
# 5 [] {'sheep_spawn_egg': 2}
# 8 [] {'sheep_spawn_egg': 1}
# 13 ['birch_log'] {'birch_log': 1}
# Negan (7, 19)
# nonuseful_items =  ['gold_ingot', 'stick', 'rabbit_hide', 'coal', 'sheep_spawn_egg', 'birch_log', 'cow_spawn_egg', 'lead', 'leather', 'oak_log', 'white_wool', 'saddle', 'spruce_log']
# gold_ingot  end  14
# gold_ingot  start  14
# stick  end  7
# stick  start  7
# coal  end  8
# coal  start  5
# birch_log  end  12
# birch_log  start  13
# cow_spawn_egg  end  2
# cow_spawn_egg  start  2
# lead  end  8
# lead  start  10
# leather  end  1
# leather  start  1
# oak_log  end  8
# oak_log  start  8
# white_wool  end  1
# white_wool  start  1
# saddle  end  1
# saddle  start  1
# spruce_log  end  5
# spruce_log  start  5
# 2 [] {'oak_boat': 1}
# 4 ['coal', 'sheep_spawn_egg'] {'coal': 3, 'sheep_spawn_egg': 1}
# hoarding_list:  ['coal']
# num_trades =  1
# 7 [] {'pufferfish': 2}
# 8 [] {'turtle_egg': 1}
# 11 [] {'tropical_fish': 1}
# 13 ['leather'] {'leather': 1}
# 14 [] {'tropical_fish': 1}
# Cosmo (2, 19)
# nonuseful_items =  ['stick', 'tropical_fish', 'cod', 'diamond_axe', 'leather', 'spruce_log', 'pufferfish', 'string', 'blue_dye', 'sheep_spawn_egg', 'cow_spawn_egg', 'lead', 'white_wool', 'spruce_planks']
# stick  end  12
# stick  start  12
# tropical_fish  end  6
# tropical_fish  start  6
# cod  end  15
# cod  start  15
# diamond_axe  end  1
# diamond_axe  start  1
# spruce_log  end  4
# spruce_log  start  4
# pufferfish  end  6
# pufferfish  start  6
# string  end  1
# string  start  1
# blue_dye  end  14
# blue_dye  start  14
# sheep_spawn_egg  end  2
# sheep_spawn_egg  start  2
# cow_spawn_egg  end  1
# cow_spawn_egg  start  1
# lead  end  3
# lead  start  3
# white_wool  end  2
# white_wool  start  2
# spruce_planks  end  9
# spruce_planks  start  9
# 9 [] {'coal': 3}
# 12 [] {'iron_ingot': 2}
# Alex (3, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'fletching_table', 'loom', 'oak_boat', 'cod', 'turtle_egg', 'leather', 'pufferfish', 'smithing_table', 'string', 'blue_dye', 'rabbit_hide', 'coal', 'iron_ingot', 'sheep_spawn_egg', 'cow_spawn_egg', 'white_wool', 'shears']
# gold_ingot  end  3
# gold_ingot  start  3
# diamond_sword  end  1
# diamond_sword  start  1
# fletching_table  end  1
# fletching_table  start  1
# loom  end  3
# loom  start  1
# oak_boat  end  1
# oak_boat  start  1
# cod  end  4
# cod  start  4
# turtle_egg  end  1
# turtle_egg  start  1
# leather  end  10
# leather  start  10
# pufferfish  end  1
# pufferfish  start  1
# smithing_table  end  1
# smithing_table  start  1
# rabbit_hide  end  1
# rabbit_hide  start  1
# coal  end  4
# coal  start  4
# iron_ingot  end  20
# iron_ingot  start  20
# sheep_spawn_egg  end  2
# sheep_spawn_egg  start  4
# cow_spawn_egg  end  3
# cow_spawn_egg  start  3
# white_wool  end  2
# white_wool  start  2
# shears  end  1
# 3 ['loom', 'shears'] {'loom': 2, 'shears': 1}
# hoarding_list:  ['loom', 'shears']
# num_trades =  1
# 5 [] {'diamond_axe': 1}
# 12 ['fletching_table'] {'fletching_table': 1}
# GeminiComp4
# Steve (7, 19)
# nonuseful_items =  ['stick', 'quartz_block', 'loom', 'leather', 'chicken', 'string', 'cooked_beef', 'blue_dye', 'porkchop', 'glass', 'sheep_spawn_egg', 'cow_spawn_egg', 'lead', 'white_wool', 'cooked_porkchop', 'shears', 'stone', 'red_glazed_terracotta']
# stick  end  1
# stick  start  1
# quartz_block  end  1
# quartz_block  start  1
# loom  end  1
# leather  end  2
# leather  start  2
# chicken  end  10
# chicken  start  9
# blue_dye  end  1
# porkchop  end  2
# porkchop  start  2
# glass  end  1
# glass  start  1
# sheep_spawn_egg  end  1
# cow_spawn_egg  end  1
# cow_spawn_egg  start  1
# lead  end  1
# lead  start  1
# shears  end  1
# stone  end  9
# stone  start  9
# red_glazed_terracotta  end  1
# red_glazed_terracotta  start  1
# 0 [] {'pufferfish': 1}
# 1 [] {'oak_boat': 1}
# 2 ['blue_dye', 'loom'] {'blue_dye': 1, 'loom': 1}
# hoarding_list:  ['blue_dye', 'loom']
# num_trades =  1
# 3 ['chicken'] {'chicken': 1}
# hoarding_list:  ['chicken']
# num_trades =  2
# 5 ['sheep_spawn_egg'] {'sheep_spawn_egg': 1}
# hoarding_list:  ['sheep_spawn_egg']
# num_trades =  3
# 11 ['shears'] {'shears': 1}
# hoarding_list:  ['shears']
# num_trades =  4
# 12 [] {'oak_boat': 1}
# Sokka (3, 19)
# nonuseful_items =  ['stick', 'quartz_block', 'tropical_fish', 'loom', 'oak_boat', 'stone_pickaxe', 'string', 'blue_dye', 'rabbit_hide', 'sheep_spawn_egg', 'cow_spawn_egg', 'lead', 'white_wool', 'shears', 'stone', 'red_glazed_terracotta', 'salmon']
# stick  end  14
# stick  start  14
# quartz_block  end  5
# quartz_block  start  5
# tropical_fish  end  8
# tropical_fish  start  8
# loom  end  6
# loom  start  6
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# string  end  9
# string  start  9
# blue_dye  end  16
# blue_dye  start  16
# rabbit_hide  end  1
# rabbit_hide  start  1
# sheep_spawn_egg  end  1
# sheep_spawn_egg  start  1
# cow_spawn_egg  end  1
# cow_spawn_egg  start  1
# lead  end  15
# lead  start  15
# white_wool  end  1
# white_wool  start  1
# shears  end  1
# shears  start  1
# stone  end  11
# stone  start  11
# red_glazed_terracotta  end  4
# red_glazed_terracotta  start  4
# salmon  end  3
# salmon  start  3
# 1 [] {'cooked_beef': 1}
# 3 [] {'cooked_porkchop': 1}
# 10 ['string'] {'string': 5}
# Negan (3, 19)
# nonuseful_items =  ['stick', 'tropical_fish', 'loom', 'oak_boat', 'leather', 'saddle', 'beef', 'chicken', 'pufferfish', 'cooked_beef', 'rabbit_stew', 'sheep_spawn_egg', 'cow_spawn_egg', 'lead', 'white_wool', 'cooked_porkchop', 'shears', 'salmon']
# stick  end  1
# stick  start  1
# tropical_fish  end  1
# tropical_fish  start  1
# loom  end  1
# loom  start  1
# oak_boat  end  1
# oak_boat  start  1
# leather  end  3
# leather  start  3
# saddle  end  1
# saddle  start  1
# beef  end  11
# beef  start  11
# chicken  end  5
# chicken  start  5
# pufferfish  end  1
# cooked_beef  end  4
# cooked_beef  start  4
# rabbit_stew  end  1
# rabbit_stew  start  1
# sheep_spawn_egg  end  8
# sheep_spawn_egg  start  9
# cow_spawn_egg  end  3
# cow_spawn_egg  start  3
# lead  end  3
# lead  start  3
# white_wool  end  8
# white_wool  start  8
# cooked_porkchop  end  1
# cooked_porkchop  start  1
# shears  end  1
# shears  start  1
# salmon  end  15
# salmon  start  15
# 5 ['pufferfish'] {'pufferfish': 1}
# hoarding_list:  ['pufferfish']
# num_trades =  1
# 9 [] {'red_glazed_terracotta': 1}
# 11 ['pufferfish'] {'pufferfish': 1}
# hoarding_list:  ['pufferfish']
# num_trades =  2
# Cosmo (2, 19)
# nonuseful_items =  ['string', 'cooked_beef', 'porkchop', 'glass', 'tropical_fish', 'rabbit_stew', 'oak_boat', 'cod', 'turtle_egg', 'cooked_porkchop', 'red_glazed_terracotta', 'beef', 'chicken', 'pufferfish']
# string  end  6
# string  start  6
# cooked_beef  end  3
# cooked_beef  start  3
# porkchop  end  18
# porkchop  start  18
# glass  end  8
# glass  start  8
# tropical_fish  end  7
# tropical_fish  start  5
# rabbit_stew  end  1
# rabbit_stew  start  1
# oak_boat  end  1
# oak_boat  start  1
# cod  end  19
# cod  start  19
# turtle_egg  end  1
# turtle_egg  start  1
# cooked_porkchop  end  8
# ...
# cooked_beef  start  2
# stick  end  3
# fletching_table  end  6
# fletching_table  start  6
# porkchop  end  2
# porkchop  start  2
# iron_ingot  end  4
# iron_ingot  start  4
# diamond_axe  end  1
# diamond_axe  start  1
# cow_spawn_egg  end  3
# cow_spawn_egg  start  3
# lead  end  9
# lead  start  16
# oak_log  end  1
# oak_log  start  1
# beef  end  2
# beef  start  10
# chicken  end  19
# chicken  start  19
# 4 ['oak_log'] {'oak_log': 1}
# 10 [] {'oak_boat': 1}
# 13 ['stick'] {'stick': 3}
# hoarding_list:  ['stick']
# num_trades =  1
# 17 [] {'salmon': 2, 'tropical_fish': 3}
# 25 ['leather'] {'leather': 10}
# Sokka (7, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'cooked_beef', 'oak_planks', 'fletching_table', 'iron_ingot', 'diamond_axe', 'oak_log', 'cooked_porkchop', 'spruce_planks', 'chicken', 'salmon']
# gold_ingot  end  2
# gold_ingot  start  2
# diamond_sword  end  1
# diamond_sword  start  1
# cooked_beef  end  2
# cooked_beef  start  6
# oak_planks  end  7
# oak_planks  start  7
# fletching_table  end  3
# fletching_table  start  4
# iron_ingot  end  13
# iron_ingot  start  13
# diamond_axe  end  1
# diamond_axe  start  1
# oak_log  end  9
# oak_log  start  10
# cooked_porkchop  end  3
# cooked_porkchop  start  7
# spruce_planks  end  7
# spruce_planks  start  8
# salmon  end  7
# salmon  start  7
# 3 [] {'leather': 4, 'lead': 1}
# 4 [] {'lead': 4}
# 8 [] {'stick': 2}
# 12 [] {'lead': 3, 'stick': 5}
# 13 [] {'lead': 3}
# 16 [] {'saddle': 1}
# 25 [] {'lead': 6}
# Negan (4, 19)
# nonuseful_items =  ['gold_ingot', 'stick', 'porkchop', 'coal', 'tropical_fish', 'rabbit_stew', 'oak_boat', 'cow_spawn_egg', 'leather', 'beef', 'salmon', 'pufferfish']
# gold_ingot  end  2
# gold_ingot  start  2
# stick  end  2
# stick  start  14
# porkchop  end  18
# porkchop  start  18
# tropical_fish  end  3
# tropical_fish  start  3
# rabbit_stew  end  1
# rabbit_stew  start  1
# oak_boat  end  1
# oak_boat  start  1
# cow_spawn_egg  end  1
# cow_spawn_egg  start  1
# beef  end  4
# beef  start  4
# salmon  end  2
# salmon  start  2
# pufferfish  end  8
# pufferfish  start  8
# 0 [] {'spruce_planks': 1, 'birch_log': 10}
# 8 [] {'spruce_planks': 1}
# 14 [] {'spruce_log': 10}
# 17 [] {'oak_log': 0}
# Cosmo (2, 19)
# nonuseful_items =  ['stick', 'oak_planks', 'tropical_fish', 'cod', 'turtle_egg', 'saddle', 'spruce_log', 'beef', 'pufferfish', 'cooked_beef', 'rabbit_stew', 'cow_spawn_egg', 'lead', 'spruce_planks', 'salmon']
# oak_planks  end  2
# oak_planks  start  2
# tropical_fish  end  3
# tropical_fish  start  3
# cod  end  15
# cod  start  15
# turtle_egg  end  1
# turtle_egg  start  1
# saddle  end  1
# saddle  start  1
# spruce_log  end  19
# spruce_log  start  19
# beef  end  6
# beef  start  6
# pufferfish  end  1
# pufferfish  start  1
# cooked_beef  end  2
# cooked_beef  start  2
# rabbit_stew  end  1
# rabbit_stew  start  1
# cow_spawn_egg  end  5
# cow_spawn_egg  start  5
# spruce_planks  end  1
# spruce_planks  start  1
# salmon  end  5
# salmon  start  5
# 12 [] {'diamond_sword': 1, 'fletching_table': 1}
# 14 [] {'coal': 5}
# Alex (4, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'smithing_table', 'stick', 'rabbit_hide', 'coal', 'tropical_fish', 'oak_boat', 'cod', 'birch_log', 'lead', 'leather', 'saddle', 'spruce_planks', 'salmon']
# gold_ingot  end  6
# gold_ingot  start  6
# diamond_sword  end  1
# diamond_sword  start  1
# smithing_table  end  10
# smithing_table  start  10
# stick  end  10
# rabbit_hide  end  9
# rabbit_hide  start  9
# coal  end  14
# coal  start  14
# tropical_fish  end  13
# tropical_fish  start  13
# cod  end  2
# cod  start  2
# birch_log  end  10
# birch_log  start  20
# leather  end  10
# leather  start  4
# saddle  end  1
# saddle  start  1
# salmon  end  1
# salmon  start  1
# 0 ['leather', 'stick'] {'leather': 10, 'stick': 10}
# hoarding_list:  ['leather', 'stick']
# num_trades =  1
# 3 [] {'cooked_beef': 4, 'cooked_porkchop': 4}
# 10 [] {'beef': 8}
# 16 [] {'chicken': 1}
# GeminiCoop7
# Steve (1, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'quartz_block', 'diamond_axe', 'birch_log', 'stone_pickaxe', 'spruce_log', 'porkchop', 'glass', 'coal', 'blue_glazed_terracotta', 'oak_log', 'cooked_porkchop', 'stone', 'spruce_planks', 'red_glazed_terracotta']
# gold_ingot  end  4
# gold_ingot  start  4
# diamond_sword  end  1
# diamond_sword  start  1
# quartz_block  end  17
# quartz_block  start  17
# diamond_axe  end  1
# diamond_axe  start  1
# birch_log  end  15
# birch_log  start  15
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# spruce_log  end  1
# spruce_log  start  1
# porkchop  end  8
# porkchop  start  8
# glass  end  11
# glass  start  11
# coal  end  10
# coal  start  10
# blue_glazed_terracotta  end  1
# blue_glazed_terracotta  start  1
# oak_log  end  4
# oak_log  start  4
# cooked_porkchop  end  3
# cooked_porkchop  start  3
# stone  end  18
# stone  start  18
# spruce_planks  end  1
# spruce_planks  start  1
# red_glazed_terracotta  end  8
# red_glazed_terracotta  start  8
# 7 [] {'pumpkin': 8, 'bread': 2}
# Sokka (2, 19)
# nonuseful_items =  ['gold_ingot', 'wheat', 'oak_planks', 'bread', 'fletching_table', 'glass', 'blue_glazed_terracotta', 'iron_ingot', 'carrot', 'diamond_axe', 'birch_log', 'spruce_log', 'pumpkin']
# gold_ingot  end  14
# gold_ingot  start  14
# wheat  end  12
# wheat  start  12
# oak_planks  end  2
# oak_planks  start  2
# bread  end  1
# bread  start  1
# fletching_table  end  1
# fletching_table  start  1
# glass  end  5
# glass  start  5
# blue_glazed_terracotta  end  1
# blue_glazed_terracotta  start  1
# iron_ingot  end  3
# iron_ingot  start  3
# carrot  end  2
# carrot  start  2
# diamond_axe  end  1
# birch_log  end  1
# birch_log  start  1
# pumpkin  end  1
# pumpkin  start  1
# 11 ['diamond_axe'] {'diamond_axe': 1}
# hoarding_list:  ['diamond_axe']
# num_trades =  1
# 14 [] {'cooked_beef': 1}
# Negan (6, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'cooked_beef', 'bread', 'quartz_block', 'glass', 'coal', 'blue_glazed_terracotta', 'rabbit_stew', 'potato', 'cooked_porkchop', 'stone', 'red_glazed_terracotta', 'beef', 'pumpkin']
# cooked_beef  end  8
# cooked_beef  start  8
# quartz_block  end  2
# quartz_block  start  2
# glass  end  4
# glass  start  4
# rabbit_stew  end  1
# rabbit_stew  start  1
# potato  end  13
# potato  start  13
# cooked_porkchop  end  6
# cooked_porkchop  start  6
# stone  end  1
# stone  start  1
# beef  end  19
# beef  start  19
# 1 [] {'spruce_planks': 4, 'oak_log': 2}
# 7 [] {'diamond_axe': 1, 'oak_log': 4}
# 10 [] {'diamond_axe': 1, 'oak_log': 10}
# 11 [] {'spruce_log': 6}
# 12 [] {'spruce_log': 12}
# 13 [] {'oak_log': 4}
# Cosmo (3, 19)
# nonuseful_items =  ['cooked_beef', 'oak_planks', 'bread', 'porkchop', 'rabbit_stew', 'carrot', 'oak_log', 'spruce_planks', 'spruce_log', 'chicken', 'mushroom_stew']
# cooked_beef  end  1
# cooked_beef  start  1
# oak_planks  end  1
# oak_planks  start  1
# bread  end  3
# bread  start  3
# porkchop  end  1
# porkchop  start  1
# rabbit_stew  end  1
# rabbit_stew  start  1
# carrot  end  15
# carrot  start  15
# chicken  end  18
# chicken  start  18
# mushroom_stew  end  1
# mushroom_stew  start  1
# 1 [] {'gold_ingot': 2, 'coal': 1}
# 12 [] {'diamond_sword': 1}
# 15 [] {'smithing_table': 2, 'fletching_table': 2}
# Alex (4, 19)
# nonuseful_items =  ['wheat', 'smithing_table', 'cooked_beef', 'fletching_table', 'porkchop', 'coal', 'carrot', 'diamond_axe', 'oak_log', 'potato', 'beef', 'chicken']
# wheat  end  8
# wheat  start  8
# smithing_table  end  9
# smithing_table  start  9
# fletching_table  end  7
# fletching_table  start  7
# porkchop  end  1
# porkchop  start  1
# coal  end  7
# coal  start  7
# carrot  end  3
# carrot  start  3
# potato  end  1
# potato  start  1
# beef  end  4
# chicken  end  1
# chicken  start  1
# 10 [] {'red_glazed_terracotta': 1, 'blue_glazed_terracotta': 8}
# 13 ['beef'] {'beef': 4}
# hoarding_list:  ['beef']
# num_trades =  1
# 14 [] {'glass': 5}
# 15 ['carrot', 'chicken'] {'carrot': 2, 'chicken': 2}
# GeminiCoop8
# Steve (4, 19)
# nonuseful_items =  ['string', 'quartz_block', 'glass', 'oak_boat', 'cod', 'birch_log', 'white_wool', 'oak_log', 'spruce_planks', 'spruce_log', 'pufferfish']
# string  end  1
# string  start  1
# glass  end  1
# glass  start  1
# oak_boat  end  1
# oak_boat  start  1
# birch_log  end  1
# birch_log  start  1
# white_wool  end  2
# white_wool  start  2
# spruce_planks  end  1
# spruce_planks  start  1
# spruce_log  end  3
# spruce_log  start  3
# pufferfish  end  8
# pufferfish  start  8
# 0 [] {'saddle': 1}
# 2 [] {'rabbit_hide': 1}
# 6 [] {'saddle': 1}
# 7 [] {'saddle': 1, 'rabbit_hide': 1}
# Sokka (3, 19)
# nonuseful_items =  ['stick', 'quartz_block', 'tropical_fish', 'birch_log', 'turtle_egg', 'stone_pickaxe', 'saddle', 'spruce_log', 'rabbit_hide', 'glass', 'blue_glazed_terracotta', 'cow_spawn_egg', 'oak_log', 'stone', 'red_glazed_terracotta']
# stick  end  6
# stick  start  6
# quartz_block  end  1
# quartz_block  start  1
# tropical_fish  end  2
# tropical_fish  start  2
# birch_log  end  1
# birch_log  start  1
# turtle_egg  end  1
# turtle_egg  start  1
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# spruce_log  end  2
# spruce_log  start  2
# rabbit_hide  end  6
# rabbit_hide  start  7
# glass  end  5
# glass  start  5
# blue_glazed_terracotta  end  4
# blue_glazed_terracotta  start  4
# cow_spawn_egg  end  6
# cow_spawn_egg  start  6
# oak_log  end  12
# oak_log  start  12
# stone  end  12
# stone  start  17
# red_glazed_terracotta  end  2
# red_glazed_terracotta  start  2
# 7 [] {'string': 1, 'white_wool': 2}
# 8 [] {'string': 1}
# 20 [] {'shears': 1}
# Negan (4, 19)
# nonuseful_items =  ['stick', 'oak_planks', 'tropical_fish', 'loom', 'cod', 'diamond_axe', 'birch_log', 'leather', 'string', 'blue_dye', 'rabbit_hide', 'sheep_spawn_egg', 'cow_spawn_egg', 'lead', 'oak_log']
# stick  end  6
# stick  start  6
# oak_planks  end  9
# oak_planks  start  9
# tropical_fish  end  9
# tropical_fish  start  9
# loom  end  1
# loom  start  1
# diamond_axe  end  1
# diamond_axe  start  1
# birch_log  end  18
# birch_log  start  18
# leather  end  19
# leather  start  19
# string  end  1
# string  start  2
# blue_dye  end  19
# blue_dye  start  19
# rabbit_hide  end  2
# rabbit_hide  start  3
# sheep_spawn_egg  end  2
# sheep_spawn_egg  start  2
# cow_spawn_egg  end  4
# cow_spawn_egg  start  4
# lead  end  10
# lead  start  10
# oak_log  end  2
# oak_log  start  2
# 2 [] {'quartz_block': 2}
# 8 [] {'stone': 5}
# 9 [] {'quartz_block': 2}
# 10 [] {'quartz_block': 1}
# Cosmo (2, 19)
# nonuseful_items =  ['stick', 'quartz_block', 'loom', 'diamond_axe', 'saddle', 'string', 'blue_glazed_terracotta', 'lead', 'oak_log', 'white_wool', 'stone', 'spruce_planks', 'red_glazed_terracotta']
# stick  end  1
# stick  start  1
# quartz_block  end  2
# quartz_block  start  2
# loom  end  4
# loom  start  4
# diamond_axe  end  1
# diamond_axe  start  1
# string  end  7
# string  start  7
# blue_glazed_terracotta  end  1
# blue_glazed_terracotta  start  1
# lead  end  6
# lead  start  6
# oak_log  end  5
# oak_log  start  5
# white_wool  end  17
# white_wool  start  17
# stone  end  2
# stone  start  2
# spruce_planks  end  4
# spruce_planks  start  4
# red_glazed_terracotta  end  2
# red_glazed_terracotta  start  2
# 0 [] {'cod': 15}
# 9 [] {'cod': 1}
# Alex (3, 19)
# nonuseful_items =  ['stick', 'quartz_block', 'cod', 'stone_pickaxe', 'saddle', 'pufferfish', 'string', 'blue_dye', 'blue_glazed_terracotta', 'sheep_spawn_egg', 'shears', 'stone', 'red_glazed_terracotta', 'salmon']
# stick  end  2
# stick  start  2
# cod  end  1
# cod  start  1
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# pufferfish  end  1
# pufferfish  start  1
# string  end  6
# string  start  6
# blue_dye  end  1
# blue_dye  start  1
# blue_glazed_terracotta  end  1
# blue_glazed_terracotta  start  1
# sheep_spawn_egg  end  1
# sheep_spawn_egg  start  1
# shears  end  1
# shears  start  1
# stone  end  1
# stone  start  1
# red_glazed_terracotta  end  2
# red_glazed_terracotta  start  2
# salmon  end  4
# salmon  start  4
# 6 [] {'oak_log': 1}
# 10 [] {'birch_log': 1}
# 20 ['string'] {'string': 1}
# GeminiCoop9
# Steve (3, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'wheat', 'bread', 'fletching_table', 'quartz_block', 'tropical_fish', 'carrot', 'oak_boat', 'turtle_egg', 'pumpkin', 'pufferfish', 'smithing_table', 'coal', 'potato']
# gold_ingot  end  3
# gold_ingot  start  3
# diamond_sword  end  1
# diamond_sword  start  1
# wheat  end  17
# wheat  start  17
# bread  end  1
# bread  start  1
# fletching_table  end  2
# fletching_table  start  2
# quartz_block  end  1
# quartz_block  start  1
# tropical_fish  end  8
# tropical_fish  start  8
# oak_boat  end  1
# oak_boat  start  1
# turtle_egg  end  1
# turtle_egg  start  1
# pumpkin  end  6
# pumpkin  start  6
# pufferfish  end  1
# pufferfish  start  1
# smithing_table  end  1
# smithing_table  start  1
# coal  end  20
# coal  start  20
# 27 [] {'cow_spawn_egg': 1}
# 37 [] {'cow_spawn_egg': 1}
# 38 ['gold_ingot'] {'gold_ingot': 1}
# Sokka (9, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'stick', 'rabbit_hide', 'quartz_block', 'blue_glazed_terracotta', 'tropical_fish', 'oak_boat', 'cod', 'cow_spawn_egg', 'lead', 'leather', 'stone', 'red_glazed_terracotta']
# stick  end  1
# stick  start  1
# rabbit_hide  end  2
# rabbit_hide  start  2
# blue_glazed_terracotta  end  5
# blue_glazed_terracotta  start  5
# tropical_fish  end  10
# tropical_fish  start  3
# oak_boat  end  1
# oak_boat  start  1
# cod  end  18
# cod  start  11
# cow_spawn_egg  end  2
# cow_spawn_egg  start  3
# lead  end  17
# lead  start  17
# leather  end  1
# leather  start  1
# stone  end  16
# stone  start  16
# red_glazed_terracotta  end  4
# red_glazed_terracotta  start  2
# 0 ['red_glazed_terracotta'] {'red_glazed_terracotta': 2}
# hoarding_list:  ['red_glazed_terracotta']
# num_trades =  1
# 2 ['cod', 'tropical_fish'] {'cod': 7, 'tropical_fish': 7}
# hoarding_list:  ['cod', 'tropical_fish']
# num_trades =  2
# 3 [] {'pumpkin': 1}
# 16 [] {'carrot': 11}
# 19 [] {'potato': 1, 'mushroom_stew': 1}
# 27 [] {'potato': 2}
# 32 [] {'potato': 14}
# 35 [] {'carrot': 6}
# 37 [] {'carrot': 1}
# Negan (2, 19)
# nonuseful_items =  ['stick', 'bread', 'fletching_table', 'tropical_fish', 'iron_ingot', 'carrot', 'cod', 'cow_spawn_egg', 'potato', 'pumpkin', 'salmon', 'pufferfish']
# stick  end  15
# stick  start  15
# bread  end  1
# bread  start  1
# fletching_table  end  1
# fletching_table  start  1
# tropical_fish  end  2
# tropical_fish  start  2
# iron_ingot  end  6
# iron_ingot  start  6
# carrot  end  8
# carrot  start  8
# cod  end  1
# cod  start  1
# cow_spawn_egg  end  3
# cow_spawn_egg  start  3
# potato  end  3
# potato  start  3
# pumpkin  end  1
# pumpkin  start  1
# salmon  end  17
# salmon  start  17
# pufferfish  end  2
# pufferfish  start  2
# 0 [] {'quartz_block': 3}
# 35 [] {'blue_glazed_terracotta': 1}
# Cosmo (3, 19)
# nonuseful_items =  ['quartz_block', 'glass', 'blue_glazed_terracotta', 'carrot', 'oak_boat', 'cod', 'turtle_egg', 'cow_spawn_egg', 'leather', 'potato', 'saddle', 'pumpkin', 'pufferfish', 'mushroom_stew']
# quartz_block  end  8
# quartz_block  start  8
# glass  end  5
# glass  start  5
# blue_glazed_terracotta  end  4
# blue_glazed_terracotta  start  4
# oak_boat  end  1
# oak_boat  start  1
# cod  end  1
# cod  start  1
# turtle_egg  end  9
# turtle_egg  start  9
# cow_spawn_egg  end  1
# cow_spawn_egg  start  1
# leather  end  11
# leather  start  11
# saddle  end  1
# saddle  start  1
# pumpkin  end  1
# pumpkin  start  1
# pufferfish  end  6
# pufferfish  start  6
# mushroom_stew  end  1
# mushroom_stew  start  1
# 16 [] {'diamond_sword': 1}
# 32 [] {'gold_ingot': 1}
# 38 [] {'coal': 1}
# Alex (3, 19)
# nonuseful_items =  ['gold_ingot', 'diamond_sword', 'wheat', 'bread', 'fletching_table', 'quartz_block', 'leather', 'stone_pickaxe', 'pumpkin', 'smithing_table', 'glass', 'blue_glazed_terracotta', 'iron_ingot', 'cow_spawn_egg', 'potato', 'stone', 'mushroom_stew']
# gold_ingot  end  15
# gold_ingot  start  15
# diamond_sword  end  1
# wheat  end  2
# wheat  start  2
# bread  end  5
# bread  start  5
# fletching_table  end  7
# fletching_table  start  7
# quartz_block  end  6
# leather  end  7
# leather  start  7
# stone_pickaxe  end  1
# stone_pickaxe  start  1
# pumpkin  end  1
# pumpkin  start  2
# smithing_table  end  6
# smithing_table  start  6
# glass  end  15
# glass  start  15
# blue_glazed_terracotta  end  1
# blue_glazed_terracotta  start  1
# iron_ingot  end  8
# iron_ingot  start  8
# cow_spawn_egg  end  3
# cow_spawn_egg  start  3
# potato  end  1
# potato  start  1
# stone  end  2
# stone  start  2
# mushroom_stew  end  1
# mushroom_stew  start  1
# 2 ['quartz_block', 'quartz_block'] {'quartz_block': 3}
# hoarding_list:  ['quartz_block', 'quartz_block']
# num_trades =  1
# 3 ['diamond_sword'] {'diamond_sword': 1}
# hoarding_list:  ['diamond_sword']
# num_trades =  2
# 19 ['quartz_block', 'quartz_block'] {'quartz_block': 1}
# hoarding_list:  ['quartz_block', 'quartz_block']
# num_trades =  3

# %%
hoarded_items_dict
# Out:
# {'GeminiBase1': [{'player': 'Sokka',
#    'items_list': [{'pumpkin': 2}],
#    'hoarded_score': 6,
#    'num_trades': 2,
#    'game_type': 'Baseline',
#    'game_name': '1'}],
#  'GeminiBase16': [{'player': 'Alex',
#    'items_list': [{'coal': 12}],
#    'hoarded_score': 12,
#    'num_trades': 1,
#    'game_type': 'Baseline',
#    'game_name': '16'}],
#  'GeminiBase18': [{'player': 'Negan',
#    'items_list': [{'oak_planks': 3}, {'string': 1}],
#    'hoarded_score': 10,
#    'num_trades': 1,
#    'game_type': 'Baseline',
#    'game_name': '18'},
#   {'player': 'Cosmo',
#    'items_list': [{'loom': 1}, {'cow_spawn_egg': 1}],
#    'hoarded_score': 6,
#    'num_trades': 2,
#    'game_type': 'Baseline',
#    'game_name': '18'}],
#  'GeminiBase2': [{'player': 'Steve',
#    'items_list': [{'coal': 1}],
#    'hoarded_score': 1,
#    'num_trades': 1,
#    'game_type': 'Baseline',
#    'game_name': '2'},
#   {'player': 'Sokka',
#    'items_list': [{'gold_ingot': 9}],
#    'hoarded_score': 9,
#    'num_trades': 1,
#    'game_type': 'Baseline',
#    'game_name': '2'}],
#  'GeminiBase3': [{'player': 'Cosmo',
#    'items_list': [{'gold_ingot': 2},
#     {'leather': 1},
#     {'cooked_beef': 5},
#     {'porkchop': 6},
#     {'cooked_porkchop': 2}],
#    'hoarded_score': 30,
#    'num_trades': 5,
#    'game_type': 'Baseline',
#    'game_name': '3'}],
#  'GeminiBase4': [{'player': 'Cosmo',
#    'items_list': [{'loom': 6}],
#    'hoarded_score': 18,
#    'num_trades': 1,
#    'game_type': 'Baseline',
#    'game_name': '4'}],
#  'GeminiBase5': [{'player': 'Alex',
#    'items_list': [{'cow_spawn_egg': 1}],
#    'hoarded_score': 3,
#    'num_trades': 1,
#    'game_type': 'Baseline',
#    'game_name': '5'}],
#  'GeminiBase8': [{'player': 'Negan',
#    'items_list': [{'wheat': 1}, {'porkchop': 1}, {'potato': 1}],
#    'hoarded_score': 3,
#    'num_trades': 1,
#    'game_type': 'Baseline',
#    'game_name': '8'},
#   {'player': 'Alex',
#    'items_list': [{'carrot': 3}, {'string': 3}, {'white_wool': 3}],
#    'hoarded_score': 9,
#    'num_trades': 1,
#    'game_type': 'Baseline',
#    'game_name': '8'}],
#  'GeminiComp1': [{'player': 'Negan',
#    'items_list': [{'lead': 3}, {'leather': 6}],
#    'hoarded_score': 9,
#    'num_trades': 2,
#    'game_type': 'Competitive',
#    'game_name': '1'},
#   {'player': 'Alex',
#    'items_list': [{'chicken': 4}],
#    'hoarded_score': 4,
#    'num_trades': 1,
#    'game_type': 'Competitive',
#    'game_name': '1'}],
#  'GeminiComp2': [],
#  'GeminiComp3': [{'player': 'Sokka',
#    'items_list': [{'cow_spawn_egg': 2}],
#    'hoarded_score': 6,
#    'num_trades': 1,
#    'game_type': 'Competitive',
#    'game_name': '3'},
#   {'player': 'Negan',
#    'items_list': [{'coal': 3}],
#    'hoarded_score': 3,
#    'num_trades': 1,
#    'game_type': 'Competitive',
#    'game_name': '3'},
#   {'player': 'Alex',
#    'items_list': [{'loom': 2}, {'shears': 1}],
#    'hoarded_score': 16,
#    'num_trades': 1,
#    'game_type': 'Competitive',
#    'game_name': '3'}],
#  'GeminiComp4': [{'player': 'Steve',
#    'items_list': [{'loom': 1},
#     {'chicken': 1},
#     {'blue_dye': 1},
#     {'sheep_spawn_egg': 1},
#     {'shears': 1}],
#    'hoarded_score': 18,
#    'num_trades': 4,
#    'game_type': 'Competitive',
#    'game_name': '4'},
#   {'player': 'Negan',
#    'items_list': [{'pufferfish': 1}],
#    'hoarded_score': 3,
#    'num_trades': 2,
#    'game_type': 'Competitive',
#    'game_name': '4'},
#   {'player': 'Cosmo',
#    'items_list': [{'tropical_fish': 2}],
#    'hoarded_score': 2,
#    'num_trades': 1,
#    'game_type': 'Competitive',
#    'game_name': '4'}],
#  'GeminiComp6': [{'player': 'Steve',
#    'items_list': [{'stick': 4}, {'potato': 5}],
#    'hoarded_score': 9,
#    'num_trades': 2,
#    'game_type': 'Competitive',
#    'game_name': '6'},
#   {'player': 'Sokka',
#    'items_list': [{'rabbit_hide': 2}],
#    'hoarded_score': 6,
#    'num_trades': 1,
#    'game_type': 'Competitive',
#    'game_name': '6'}],
#  'GeminiComp7': [{'player': 'Sokka',
#    'items_list': {'bread': 6},
#    'hoarded_score': 18,
#    'num_trades': 1,
#    'game_type': 'Competitive',
#    'game_name': '7'}],
#  'GeminiComp8': [{'player': 'Steve',
#    'items_list': [{'rabbit_hide': 1}, {'leather': 5}],
#    'hoarded_score': 8,
#    'num_trades': 2,
#    'game_type': 'Competitive',
#    'game_name': '8'}],
#  'GeminiComp9': [{'player': 'Sokka',
#    'items_list': [{'gold_ingot': 1}, {'smithing_table': 2}],
#    'hoarded_score': 7,
#    'num_trades': 3,
#    'game_type': 'Competitive',
#    'game_name': '9'},
#   {'player': 'Negan',
#    'items_list': [{'birch_log': 5}],
#    'hoarded_score': 5,
#    'num_trades': 1,
#    'game_type': 'Competitive',
#    'game_name': '9'},
#   {'player': 'Cosmo',
#    'items_list': [{'coal': 1}, {'iron_ingot': 1}],
#    'hoarded_score': 2,
#    'num_trades': 2,
#    'game_type': 'Competitive',
#    'game_name': '9'},
#   {'player': 'Alex',
#    'items_list': [{'smithing_table': 1}],
#    'hoarded_score': 3,
#    'num_trades': 1,
#    'game_type': 'Competitive',
#    'game_name': '9'}],
#  'GeminiCoop1': [{'player': 'Negan',
#    'items_list': [{'rabbit_hide': 9}, {'lead': 5}],
#    'hoarded_score': 32,
#    'num_trades': 3,
#    'game_type': 'Cooperative',
#    'game_name': '1'}],
#  'GeminiCoop3': [{'player': 'Negan',
#    'items_list': [{'potato': 16}],
#    'hoarded_score': 16,
#    'num_trades': 2,
#    'game_type': 'Cooperative',
#    'game_name': '3'}],
#  'GeminiCoop4': [{'player': 'Steve',
#    'items_list': [{'spruce_log': 4}],
#    'hoarded_score': 4,
#    'num_trades': 1,
#    'game_type': 'Cooperative',
#    'game_name': '4'}],
#  'GeminiCoop5': [{'player': 'Steve',
#    'items_list': [{'coal': 10}],
#    'hoarded_score': 10,
#    'num_trades': 1,
#    'game_type': 'Cooperative',
#    'game_name': '5'},
#   {'player': 'Alex',
#    'items_list': [{'lead': 1}],
#    'hoarded_score': 1,
#    'num_trades': 1,
#    'game_type': 'Cooperative',
#    'game_name': '5'}],
#  'GeminiCoop6': [{'player': 'Steve',
#    'items_list': [{'stick': 3}],
#    'hoarded_score': 3,
#    'num_trades': 1,
#    'game_type': 'Cooperative',
#    'game_name': '6'},
#   {'player': 'Alex',
#    'items_list': [{'stick': 10}, {'leather': 6}],
#    'hoarded_score': 16,
#    'num_trades': 1,
#    'game_type': 'Cooperative',
#    'game_name': '6'}],
#  'GeminiCoop7': [{'player': 'Sokka',
#    'items_list': [{'diamond_axe': 1}],
#    'hoarded_score': 10,
#    'num_trades': 1,
#    'game_type': 'Cooperative',
#    'game_name': '7'},
#   {'player': 'Alex',
#    'items_list': [{'beef': 4}],
#    'hoarded_score': 4,
#    'num_trades': 1,
#    'game_type': 'Cooperative',
#    'game_name': '7'}],
#  'GeminiCoop8': [],
#  'GeminiCoop9': [{'player': 'Sokka',
#    'items_list': [{'tropical_fish': 7},
#     {'cod': 7},
#     {'red_glazed_terracotta': 2}],
#    'hoarded_score': 20,
#    'num_trades': 2,
#    'game_type': 'Cooperative',
#    'game_name': '9'},
#   {'player': 'Alex',
#    'items_list': {'quartz_block': 4, 'diamond_sword': 1},
#    'hoarded_score': 14,
#    'num_trades': 3,
#    'game_type': 'Cooperative',
#    'game_name': '9'}]}

# %%
hoarded_items_df_dict = {filename: df.from_records(hoarded_items_dict[filename]) for filename in hoarded_items_dict if hoarded_items_dict[filename] != []}
hoarded_items_df_dict.keys()
# Out:
# dict_keys(['GeminiBase1', 'GeminiBase16', 'GeminiBase18', 'GeminiBase2', 'GeminiBase3', 'GeminiBase4', 'GeminiBase5', 'GeminiBase8', 'GeminiComp1', 'GeminiComp3', 'GeminiComp4', 'GeminiComp6', 'GeminiComp7', 'GeminiComp8', 'GeminiComp9', 'GeminiCoop1', 'GeminiCoop3', 'GeminiCoop4', 'GeminiCoop5', 'GeminiCoop6', 'GeminiCoop7', 'GeminiCoop9'])

# %%
master_hoarded_items_df = df(columns=hoarded_items_df_dict[filename].columns)
print(master_hoarded_items_df.shape)
for filename in hoarded_items_df_dict:
    master_hoarded_items_df = pd.concat([master_hoarded_items_df, hoarded_items_df_dict[filename]])
    print(filename, hoarded_items_df_dict[filename].shape, master_hoarded_items_df.shape)    
master_hoarded_items_df
# Out:
# (0, 6)
# GeminiBase1 (1, 6) (1, 6)
# GeminiBase16 (1, 6) (2, 6)
# GeminiBase18 (2, 6) (4, 6)
# GeminiBase2 (2, 6) (6, 6)
# GeminiBase3 (1, 6) (7, 6)
# GeminiBase4 (1, 6) (8, 6)
# GeminiBase5 (1, 6) (9, 6)
# GeminiBase8 (2, 6) (11, 6)
# GeminiComp1 (2, 6) (13, 6)
# GeminiComp3 (3, 6) (16, 6)
# GeminiComp4 (3, 6) (19, 6)
# GeminiComp6 (2, 6) (21, 6)
# GeminiComp7 (1, 6) (22, 6)
# GeminiComp8 (1, 6) (23, 6)
# GeminiComp9 (4, 6) (27, 6)
# GeminiCoop1 (1, 6) (28, 6)
# GeminiCoop3 (1, 6) (29, 6)
# GeminiCoop4 (1, 6) (30, 6)
# GeminiCoop5 (2, 6) (32, 6)
# GeminiCoop6 (2, 6) (34, 6)
# GeminiCoop7 (2, 6) (36, 6)
# GeminiCoop9 (2, 6) (38, 6)
#   player                                         items_list hoarded_score  \
# 0  Sokka                                   [{'pumpkin': 2}]             6
# 0   Alex                                     [{'coal': 12}]            12
# 0  Negan                 [{'oak_planks': 3}, {'string': 1}]            10
# 1  Cosmo                [{'loom': 1}, {'cow_spawn_egg': 1}]             6
# 0  Steve                                      [{'coal': 1}]             1
# 1  Sokka                                [{'gold_ingot': 9}]             9
# 0  Cosmo  [{'gold_ingot': 2}, {'leather': 1}, {'cooked_b...            30
# 0  Cosmo                                      [{'loom': 6}]            18
# 0   Alex                             [{'cow_spawn_egg': 1}]             3
# 0  Negan     [{'wheat': 1}, {'porkchop': 1}, {'potato': 1}]             3
# 1   Alex  [{'carrot': 3}, {'string': 3}, {'white_wool': 3}]             9
# 0  Negan                      [{'lead': 3}, {'leather': 6}]             9
# 1   Alex                                   [{'chicken': 4}]             4
# 0  Sokka                             [{'cow_spawn_egg': 2}]             6
# 1  Negan                                      [{'coal': 3}]             3
# 2   Alex                       [{'loom': 2}, {'shears': 1}]            16
# 0  Steve  [{'loom': 1}, {'chicken': 1}, {'blue_dye': 1},...            18
# 1  Negan                                [{'pufferfish': 1}]             3
# 2  Cosmo                             [{'tropical_fish': 2}]             2
# 0  Steve                      [{'stick': 4}, {'potato': 5}]             9
# 1  Sokka                               [{'rabbit_hide': 2}]             6
# 0  Sokka                                       {'bread': 6}            18
# 0  Steve               [{'rabbit_hide': 1}, {'leather': 5}]             8
# 0  Sokka         [{'gold_ingot': 1}, {'smithing_table': 2}]             7
# 1  Negan                                 [{'birch_log': 5}]             5
# 2  Cosmo                   [{'coal': 1}, {'iron_ingot': 1}]             2
# 3   Alex                            [{'smithing_table': 1}]             3
# 0  Negan                  [{'rabbit_hide': 9}, {'lead': 5}]            32
# 0  Negan                                   [{'potato': 16}]            16
# 0  Steve                                [{'spruce_log': 4}]             4
# 0  Steve                                     [{'coal': 10}]            10
# 1   Alex                                      [{'lead': 1}]             1
# 0  Steve                                     [{'stick': 3}]             3
# 1   Alex                    [{'stick': 10}, {'leather': 6}]            16
# 0  Sokka                               [{'diamond_axe': 1}]            10
# 1   Alex                                      [{'beef': 4}]             4
# 0  Sokka  [{'tropical_fish': 7}, {'cod': 7}, {'red_glaze...            20
# 1   Alex            {'quartz_block': 4, 'diamond_sword': 1}            14
#
#   num_trades    game_type game_name
# 0          2     Baseline         1
# 0          1     Baseline        16
# 0          1     Baseline        18
# 1          2     Baseline        18
# 0          1     Baseline         2
# 1          1     Baseline         2
# 0          5     Baseline         3
# 0          1     Baseline         4
# 0          1     Baseline         5
# 0          1     Baseline         8
# 1          1     Baseline         8
# 0          2  Competitive         1
# 1          1  Competitive         1
# 0          1  Competitive         3
# 1          1  Competitive         3
# 2          1  Competitive         3
# 0          4  Competitive         4
# 1          2  Competitive         4
# 2          1  Competitive         4
# 0          2  Competitive         6
# 1          1  Competitive         6
# 0          1  Competitive         7
# 0          2  Competitive         8
# 0          3  Competitive         9
# 1          1  Competitive         9
# 2          2  Competitive         9
# 3          1  Competitive         9
# 0          3  Cooperative         1
# 0          2  Cooperative         3
# 0          1  Cooperative         4
# 0          1  Cooperative         5
# 1          1  Cooperative         5
# 0          1  Cooperative         6
# 1          1  Cooperative         6
# 0          1  Cooperative         7
# 1          1  Cooperative         7
# 0          2  Cooperative         9
# 1          3  Cooperative         9

# %%
master_hoarded_items_df.to_excel('geminiAgents-Hoarding-Items-df_updated.xlsx')

# %%
game_trades_df_dict.keys()
# Out:
# dict_keys(['Agents_A10', 'Agents_A3', 'Agents_A4', 'Agents_A5', 'Agents_A6', 'Agents_A7', 'Agents_A8', 'Agents_A9', 'Agents_B10', 'Agents_B3', 'Agents_B4', 'Agents_B5', 'Agents_B6', 'Agents_B7', 'Agents_B8', 'Agents_B9', 'Agents_C1', 'Agents_C2', 'Agents_C3', 'Agents_C4', 'Agents_C5', 'Agents_C6', 'Agents_C7', 'Agents_C8'])

# %%
game_trades_df_dict['']
